# %%
# Import libraries
import os
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import register_matplotlib_converters  #Register pandas formatters and converters with matplotlib.
from pylab import rcParams      # for customizing matplotlib graphs.
sns.set_style("whitegrid")

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import accuracy_score, balanced_accuracy_score, plot_confusion_matrix
from sklearn import set_config
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline  
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import MinMaxScaler

# %%
from sklearn.tree          import DecisionTreeClassifier
from sklearn.ensemble      import RandomForestClassifier
from sklearn.ensemble      import ExtraTreesClassifier
from sklearn.ensemble      import AdaBoostClassifier
from sklearn.ensemble      import GradientBoostingClassifier
from sklearn.experimental  import enable_hist_gradient_boosting # Necesary for HistGradientBoostingClassifier
from sklearn.ensemble      import HistGradientBoostingClassifier
from xgboost               import XGBClassifier
from lightgbm              import LGBMClassifier
from catboost              import CatBoostClassifier
from sklearn.neighbors     import KNeighborsClassifier
from sklearn.linear_model  import LogisticRegression
from sklearn.svm           import SVC

# %%
df = pd.read_csv('heart.csv')
df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace = True)

# %%
## chainging numerical col 'chol' into categorical column:
df['chol']= pd.cut(df['chol'], bins=[0,200,239,564], labels = [0,1,2]) #0-High, 1-Borderline high, 2-High
df['trtbps']= pd.cut(df['trtbps'], bins=[90,120,139,200], labels = [0,1,2])
df['age'] = pd.cut(df['age'], bins=[25,53,80], labels = [0, 1])
df = df.astype({'trtbps':'float64','chol':'float64', 'age':'float64'})

# %%
df['chol_bps'] = df['chol']+df['trtbps']
df.drop(['chol','trtbps'], axis=1, inplace=True)
df
# Out:
#      age  sex  cp  fbs  restecg  thalachh  exng  oldpeak  slp  caa  thall  \
# 0    1.0    1   3    1        0       150     0      2.3    0    0      1
# 1    0.0    1   2    0        1       187     0      3.5    0    0      2
# 2    0.0    0   1    0        0       172     0      1.4    2    0      2
# 3    1.0    1   1    0        1       178     0      0.8    2    0      2
# 4    1.0    0   0    0        1       163     1      0.6    2    0      2
# ..   ...  ...  ..  ...      ...       ...   ...      ...  ...  ...    ...
# 297  1.0    0   0    0        1       123     1      0.2    1    0      3
# 298  0.0    1   3    0        1       132     0      1.2    1    0      3
# 299  1.0    1   0    1        1       141     0      3.4    1    2      3
# 300  1.0    1   0    0        1       115     1      1.2    1    1      3
# 301  1.0    0   1    0        0       174     0      0.0    1    1      2
#
#      output  chol_bps
# 0         1       3.0
# 1         1       3.0
# 2         1       2.0
# 3         1       1.0
# 4         1       2.0
# ..      ...       ...
# 297       0       4.0
# 298       0       2.0
# 299       0       2.0
# 300       0       1.0
# 301       0       2.0
#
# [302 rows x 13 columns]

# %%
# data agumentation
new_df = df.copy()
def get_data(data):
    gen_data = data
    for restecg_values in data['restecg'].unique():
        new_data = gen_data[gen_data['restecg']== restecg_values]
        thalachh_std = new_data['thalachh'].std()
        oldpeak_std = new_data['oldpeak'].std()

        for i in gen_data[gen_data['restecg']== restecg_values].index:
            if np.random.randint(2)==1:
                gen_data['thalachh'].values[i] += thalachh_std/10   
            else:
                gen_data['thalachh'].values[i] -= thalachh_std/10
            if np.random.randint(2)==1:
                gen_data['oldpeak'].values[i] += oldpeak_std/10
            else:
                gen_data['oldpeak'].values[i] -= oldpeak_std/10
    return gen_data
print(df.head())  
std_data = get_data(new_df)
std_data.head()
# Out:
#    age  sex  cp  fbs  restecg  thalachh  exng  oldpeak  slp  caa  thall  \
# 0  1.0    1   3    1        0       150     0      2.3    0    0      1
# 1  0.0    1   2    0        1       187     0      3.5    0    0      2
# 2  0.0    0   1    0        0       172     0      1.4    2    0      2
# 3  1.0    1   1    0        1       178     0      0.8    2    0      2
# 4  1.0    0   0    0        1       163     1      0.6    2    0      2
#
#    output  chol_bps
# 0       1       3.0
# 1       1       3.0
# 2       1       2.0
# 3       1       1.0
# 4       1       2.0
#    age  sex  cp  fbs  restecg  thalachh  exng   oldpeak  slp  caa  thall  \
# 0  1.0    1   3    1        0       147     0  2.421468    0    0      1
# 1  0.0    1   2    0        1       189     0  3.605561    0    0      2
# 2  0.0    0   1    0        0       174     0  1.521468    2    0      2
# 3  1.0    1   1    0        1       175     0  0.905561    2    0      2
# 4  1.0    0   0    0        1       160     1  0.494439    2    0      2
#
#    output  chol_bps
# 0       1       3.0
# 1       1       3.0
# 2       1       2.0
# 3       1       1.0
# 4       1       2.0

# %%
x= df.drop(['output'], axis=1)
y = df.output
cat_fe = [ 'sex','cp','fbs','restecg','exng','slp','caa','thall','age']
num_fe = ['thalachh','oldpeak','chol_bps']

x_train, x_test, y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=0, stratify=y)

extra_sample = std_data.sample(std_data.shape[0]//3)
x_train = pd.concat([x_train, extra_sample.drop(['output'], axis=1)])
y_train = pd.concat([y_train, extra_sample['output']])

# %%
s_col = ['oldpeak', 'chol_bps']
scaler = MinMaxScaler()
for d in s_col:
    train_array = x_train[d].to_numpy()
    test_array = x_test[d].to_numpy()
    train_array = train_array.reshape(-1,1)
    test_array = test_array.reshape(-1,1)

    scaler.fit(train_array)
    x_train[d] = scaler.transform(train_array)
    x_test[d] = scaler.transform(test_array)

x_train.head()
# Out:
# C:\Users\rnr31\AppData\Local\Temp\ipykernel_14356\866375025.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test[d] = scaler.transform(test_array)
# C:\Users\rnr31\AppData\Local\Temp\ipykernel_14356\866375025.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test[d] = scaler.transform(test_array)
#      age  sex  cp  fbs  restecg  thalachh  exng   oldpeak  slp  caa  thall  \
# 268  1.0    1   0    1        0       103     1  0.300879    0    0      3
# 190  1.0    1   0    0        0       131     1  0.405747    1    3      3
# 15   0.0    0   2    0        1       158     0  0.300879    1    0      2
# 223  1.0    1   0    0        1       126     1  0.510615    1    1      3
# 249  0.0    1   0    0        1       122     1  0.755308    1    3      3
#
#      chol_bps
# 268      0.75
# 190      0.50
# 15       0.25
# 223      0.25
# 249      1.00

# %%
num_4_classifiers = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value=-9999))
])
cat_4_classifiers = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value=-9999))
])
classifier_prepro = ColumnTransformer(transformers=[
    ('num', num_4_classifiers, num_fe),
    ('cat',cat_4_classifiers, cat_fe)
], remainder='drop')

# %%
tree_classifiers = {
  "KNN": KNeighborsClassifier(),
  "svm": SVC(kernel='linear', C=2.0),
  "Logistic": LogisticRegression(C= 0.5, penalty= 'l1', solver= 'liblinear'),
  "Decision Tree": DecisionTreeClassifier(),
  "Extra Trees": ExtraTreesClassifier(n_estimators=100),
  "Random Forest": RandomForestClassifier(n_estimators=100),
  "AdaBoost": AdaBoostClassifier(n_estimators=100),
  "Skl GBM": GradientBoostingClassifier(n_estimators=100),
  "Skl HistGBM": HistGradientBoostingClassifier(max_iter=100),
  "XGBoost": XGBClassifier(n_estimators=100),
  "LightGBM": LGBMClassifier(n_estimators=100),
  "CatBoost":  CatBoostClassifier(depth= 9, iterations= 80, learning_rate= 0.04),
}
tree_classifiers= {name:make_pipeline(classifier_prepro, model) for name, model in tree_classifiers.items()}
tree_classifiers["AdaBoost"]
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value=-9999,
#                                                                                  strategy='constant'))]),
#                                                   ['thalachh', 'oldpeak',
#                                                    'chol_bps']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value=-9999,
#                                                                                  strategy='constant'))]),
#                                                   ['sex', 'cp', 'fbs',
#                                                    'restecg', 'exng', 'slp',
#                                                    'caa', 'thall', 'age'])])),
#                 ('adaboostclassifier', AdaBoostClassifier(n_estimators=100))])

# %%
results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})

for model_name, model in tree_classifiers.items():
    start_time = time.time()
    model.fit(x_train, y_train)
    total_time = time.time()-start_time
    pred = model.predict(x_test)
    results = results.append({"Model":    model_name,
                            "Accuracy": accuracy_score(y_test, pred)*100,
                            "Bal Acc.": balanced_accuracy_score(y_test, pred)*100,
                            "Time":     total_time},
                            ignore_index=True)

results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
results_ord.index += 1 
results_ord.style.bar(subset=['Accuracy', 'Bal Acc.'], vmin=0, vmax=100, color='#5fba7d')
# Out:
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:37:48] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0:	learn: 0.6836775	total: 174ms	remaining: 13.8s
# 1:	learn: 0.6742422	total: 179ms	remaining: 6.97s
# 2:	learn: 0.6624048	total: 182ms	remaining: 4.68s
# 3:	learn: 0.6522540	total: 185ms	remaining: 3.51s
# 4:	learn: 0.6418691	total: 188ms	remaining: 2.81s
# 5:	learn: 0.6330721	total: 190ms	remaining: 2.35s
# 6:	learn: 0.6239374	total: 194ms	remaining: 2.02s
# 7:	learn: 0.6157699	total: 196ms	remaining: 1.77s
# 8:	learn: 0.6095114	total: 199ms	remaining: 1.57s
# 9:	learn: 0.6032378	total: 201ms	remaining: 1.41s
# 10:	learn: 0.5950568	total: 203ms	remaining: 1.27s
# 11:	learn: 0.5868618	total: 205ms	remaining: 1.16s
# 12:	learn: 0.5786771	total: 208ms	remaining: 1.07s
# 13:	learn: 0.5694829	total: 209ms	remaining: 983ms
# 14:	learn: 0.5620192	total: 211ms	remaining: 913ms
# 15:	learn: 0.5550064	total: 213ms	remaining: 852ms
# 16:	learn: 0.5499187	total: 215ms	remaining: 797ms
# 17:	learn: 0.5444778	total: 217ms	remaining: 748ms
# 18:	learn: 0.5390296	total: 219ms	remaining: 704ms
# 19:	learn: 0.5338017	total: 221ms	remaining: 664ms
# 20:	learn: 0.5251406	total: 223ms	remaining: 625ms
# 21:	learn: 0.5210496	total: 225ms	remaining: 593ms
# 22:	learn: 0.5140639	total: 227ms	remaining: 563ms
# 23:	learn: 0.5093791	total: 229ms	remaining: 535ms
# 24:	learn: 0.5052189	total: 231ms	remaining: 509ms
# 25:	learn: 0.5001878	total: 234ms	remaining: 485ms
# 26:	learn: 0.4948294	total: 236ms	remaining: 463ms
# 27:	learn: 0.4894381	total: 238ms	remaining: 442ms
# 28:	learn: 0.4852231	total: 241ms	remaining: 423ms
# 29:	learn: 0.4802123	total: 243ms	remaining: 404ms
# 30:	learn: 0.4746327	total: 244ms	remaining: 386ms
# 31:	learn: 0.4704689	total: 246ms	remaining: 369ms
# 32:	learn: 0.4666718	total: 248ms	remaining: 354ms
# 33:	learn: 0.4617513	total: 251ms	remaining: 339ms
# 34:	learn: 0.4573311	total: 253ms	remaining: 326ms
# 35:	learn: 0.4519421	total: 255ms	remaining: 311ms
# 36:	learn: 0.4474892	total: 257ms	remaining: 299ms
# 37:	learn: 0.4432697	total: 259ms	remaining: 286ms
# 38:	learn: 0.4394475	total: 261ms	remaining: 274ms
# 39:	learn: 0.4342731	total: 261ms	remaining: 261ms
# 40:	learn: 0.4302157	total: 264ms	remaining: 251ms
# 41:	learn: 0.4258853	total: 266ms	remaining: 240ms
# 42:	learn: 0.4216203	total: 266ms	remaining: 229ms
# 43:	learn: 0.4169846	total: 266ms	remaining: 218ms
# 44:	learn: 0.4137368	total: 269ms	remaining: 209ms
# 45:	learn: 0.4107328	total: 271ms	remaining: 200ms
# 46:	learn: 0.4073938	total: 273ms	remaining: 192ms
# 47:	learn: 0.4046616	total: 275ms	remaining: 183ms
# 48:	learn: 0.4016449	total: 277ms	remaining: 175ms
# 49:	learn: 0.3987823	total: 279ms	remaining: 167ms
# 50:	learn: 0.3956185	total: 281ms	remaining: 160ms
# 51:	learn: 0.3928951	total: 283ms	remaining: 152ms
# 52:	learn: 0.3901949	total: 285ms	remaining: 145ms
# 53:	learn: 0.3872814	total: 287ms	remaining: 138ms
# 54:	learn: 0.3846520	total: 289ms	remaining: 131ms
# 55:	learn: 0.3816695	total: 291ms	remaining: 125ms
# 56:	learn: 0.3789902	total: 293ms	remaining: 118ms
# 57:	learn: 0.3762949	total: 295ms	remaining: 112ms
# 58:	learn: 0.3733095	total: 296ms	remaining: 105ms
# 59:	learn: 0.3703151	total: 298ms	remaining: 99.3ms
# 60:	learn: 0.3679962	total: 300ms	remaining: 93.5ms
# 61:	learn: 0.3649775	total: 302ms	remaining: 87.8ms
# 62:	learn: 0.3618313	total: 304ms	remaining: 82.1ms
# 63:	learn: 0.3594214	total: 306ms	remaining: 76.5ms
# 64:	learn: 0.3570585	total: 308ms	remaining: 71.1ms
# 65:	learn: 0.3549210	total: 310ms	remaining: 65.8ms
# 66:	learn: 0.3522414	total: 312ms	remaining: 60.5ms
# 67:	learn: 0.3490104	total: 314ms	remaining: 55.5ms
# 68:	learn: 0.3463515	total: 315ms	remaining: 50.2ms
# 69:	learn: 0.3442358	total: 317ms	remaining: 45.3ms
# 70:	learn: 0.3419788	total: 319ms	remaining: 40.5ms
# 71:	learn: 0.3392000	total: 320ms	remaining: 35.5ms
# 72:	learn: 0.3373880	total: 322ms	remaining: 30.8ms
# 73:	learn: 0.3355901	total: 323ms	remaining: 26.2ms
# 74:	learn: 0.3334378	total: 325ms	remaining: 21.7ms
# 75:	learn: 0.3313853	total: 327ms	remaining: 17.2ms
# 76:	learn: 0.3295563	total: 329ms	remaining: 12.8ms
# 77:	learn: 0.3274746	total: 332ms	remaining: 8.51ms
# 78:	learn: 0.3251744	total: 334ms	remaining: 4.22ms
# 79:	learn: 0.3233871	total: 336ms	remaining: 0us
# <style  type="text/css" >
# #T_eff5e80f_a852_11ec_bbe7_48a472d2776erow0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 90.2%, transparent 90.2%);
#         }#T_eff5e80f_a852_11ec_bbe7_48a472d2776erow0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 90.1%, transparent 90.1%);
#         }#T_eff5e80f_a852_11ec_bbe7_48a472d2776erow1_col1,#T_eff5e80f_a852_11ec_bbe7_48a472d2776erow2_col1,#T_eff5e80f_a852_11ec_bbe7_48a472d2776erow3_col1,#T_eff5e80f_a852_11ec_bbe7_48a472d2776erow4_col1,#T_eff5e80f_a852_11ec_bbe7_48a472d2776erow5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 88.5%, transparent 88.5%);
#         }#T_eff5e80f_a852_11ec_bbe7_48a472d2776erow1_col2,#T_eff5e80f_a852_11ec_bbe7_48a472d2776erow5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 88.0%, transparent 88.0%);
#         }#T_eff5e80f_a852_11ec_bbe7_48a472d2776erow2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 88.3%, transparent 88.3%);
#         }#T_eff5e80f_a852_11ec_bbe7_48a472d2776erow3_col2,#T_eff5e80f_a852_11ec_bbe7_48a472d2776erow4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 88.6%, transparent 88.6%);
#         }#T_eff5e80f_a852_11ec_bbe7_48a472d2776erow6_col1,#T_eff5e80f_a852_11ec_bbe7_48a472d2776erow7_col1,#T_eff5e80f_a852_11ec_bbe7_48a472d2776erow8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 86.9%, transparent 86.9%);
#         }#T_eff5e80f_a852_11ec_bbe7_48a472d2776erow6_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 86.3%, transparent 86.3%);
#         }#T_eff5e80f_a852_11ec_bbe7_48a472d2776erow7_col2,#T_eff5e80f_a852_11ec_bbe7_48a472d2776erow8_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 86.8%, transparent 86.8%);
#         }#T_eff5e80f_a852_11ec_bbe7_48a472d2776erow9_col1,#T_eff5e80f_a852_11ec_bbe7_48a472d2776erow10_col1,#T_eff5e80f_a852_11ec_bbe7_48a472d2776erow11_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 82.0%, transparent 82.0%);
#         }#T_eff5e80f_a852_11ec_bbe7_48a472d2776erow9_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 81.4%, transparent 81.4%);
#         }#T_eff5e80f_a852_11ec_bbe7_48a472d2776erow10_col2,#T_eff5e80f_a852_11ec_bbe7_48a472d2776erow11_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 81.7%, transparent 81.7%);
#         }</style><table id="T_eff5e80f_a852_11ec_bbe7_48a472d2776e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >Bal Acc.</th>        <th class="col_heading level0 col3" >Time</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_eff5e80f_a852_11ec_bbe7_48a472d2776elevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow0_col0" class="data row0 col0" >Skl HistGBM</td>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow0_col1" class="data row0 col1" >90.163934</td>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow0_col2" class="data row0 col2" >90.097403</td>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow0_col3" class="data row0 col3" >0.379945</td>
#             </tr>
#             <tr>
#                         <th id="T_eff5e80f_a852_11ec_bbe7_48a472d2776elevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow1_col0" class="data row1 col0" >Logistic</td>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow1_col1" class="data row1 col1" >88.524590</td>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow1_col2" class="data row1 col2" >88.041126</td>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow1_col3" class="data row1 col3" >0.011996</td>
#             </tr>
#             <tr>
#                         <th id="T_eff5e80f_a852_11ec_bbe7_48a472d2776elevel0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow2_col0" class="data row2 col0" >Extra Trees</td>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow2_col1" class="data row2 col1" >88.524590</td>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow2_col2" class="data row2 col2" >88.311688</td>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow2_col3" class="data row2 col3" >0.109352</td>
#             </tr>
#             <tr>
#                         <th id="T_eff5e80f_a852_11ec_bbe7_48a472d2776elevel0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow3_col0" class="data row3 col0" >Skl GBM</td>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow3_col1" class="data row3 col1" >88.524590</td>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow3_col2" class="data row3 col2" >88.582251</td>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow3_col3" class="data row3 col3" >0.080816</td>
#             </tr>
#             <tr>
#                         <th id="T_eff5e80f_a852_11ec_bbe7_48a472d2776elevel0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow4_col0" class="data row4 col0" >LightGBM</td>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow4_col1" class="data row4 col1" >88.524590</td>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow4_col2" class="data row4 col2" >88.582251</td>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow4_col3" class="data row4 col3" >0.064826</td>
#             </tr>
#             <tr>
#                         <th id="T_eff5e80f_a852_11ec_bbe7_48a472d2776elevel0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow5_col0" class="data row5 col0" >CatBoost</td>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow5_col1" class="data row5 col1" >88.524590</td>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow5_col2" class="data row5 col2" >88.041126</td>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow5_col3" class="data row5 col3" >1.780566</td>
#             </tr>
#             <tr>
#                         <th id="T_eff5e80f_a852_11ec_bbe7_48a472d2776elevel0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow6_col0" class="data row6 col0" >svm</td>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow6_col1" class="data row6 col1" >86.885246</td>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow6_col2" class="data row6 col2" >86.255411</td>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow6_col3" class="data row6 col3" >0.089296</td>
#             </tr>
#             <tr>
#                         <th id="T_eff5e80f_a852_11ec_bbe7_48a472d2776elevel0_row7" class="row_heading level0 row7" >8</th>
#                         <td id="T_eff5e80f_a852_11ec_bbe7_48a472d2776erow7_col0" class="data r
