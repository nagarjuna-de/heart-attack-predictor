# %%
# Import libraries
import os
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import register_matplotlib_converters  #Register pandas formatters and converters with matplotlib.
from pylab import rcParams      # for customizing matplotlib graphs.
sns.set_style("whitegrid")

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import accuracy_score, balanced_accuracy_score, plot_confusion_matrix
from sklearn import set_config
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline  
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import MinMaxScaler

# %%
from sklearn.tree          import DecisionTreeClassifier
from sklearn.ensemble      import RandomForestClassifier
from sklearn.ensemble      import ExtraTreesClassifier
from sklearn.ensemble      import AdaBoostClassifier
from sklearn.ensemble      import GradientBoostingClassifier
from sklearn.experimental  import enable_hist_gradient_boosting # Necesary for HistGradientBoostingClassifier
from sklearn.ensemble      import HistGradientBoostingClassifier
from xgboost               import XGBClassifier
from lightgbm              import LGBMClassifier
from catboost              import CatBoostClassifier
from sklearn.neighbors     import KNeighborsClassifier
from sklearn.linear_model  import LogisticRegression
from sklearn.svm           import SVC
# Out:
# /Users/felixschekerka/opt/anaconda3/envs/strive/lib/python3.9/site-packages/sklearn/experimental/enable_hist_gradient_boosting.py:16: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   warnings.warn(

# %%
df = pd.read_csv('heart.csv')
df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace = True)

# %%
## chainging numerical col 'chol' into categorical column:
df['chol']= pd.cut(df['chol'], bins=[0,200,239,564], labels = [0,1,2]) #0-High, 1-Borderline high, 2-High
df['trtbps']= pd.cut(df['trtbps'], bins=[90,120,139,200], labels = [0,1,2])
df['age'] = pd.cut(df['age'], bins=[25,53,80], labels = [0, 1])
df = df.astype({'trtbps':'float64','chol':'float64', 'age':'float64'})

# %%
df['chol_bps'] = df['chol']+df['trtbps']
df.drop(['chol','trtbps'], axis=1, inplace=True)
df
# Out:
#      age  sex  cp  fbs  restecg  thalachh  exng  oldpeak  slp  caa  thall  \
# 0    1.0    1   3    1        0       150     0      2.3    0    0      1
# 1    0.0    1   2    0        1       187     0      3.5    0    0      2
# 2    0.0    0   1    0        0       172     0      1.4    2    0      2
# 3    1.0    1   1    0        1       178     0      0.8    2    0      2
# 4    1.0    0   0    0        1       163     1      0.6    2    0      2
# ..   ...  ...  ..  ...      ...       ...   ...      ...  ...  ...    ...
# 297  1.0    0   0    0        1       123     1      0.2    1    0      3
# 298  0.0    1   3    0        1       132     0      1.2    1    0      3
# 299  1.0    1   0    1        1       141     0      3.4    1    2      3
# 300  1.0    1   0    0        1       115     1      1.2    1    1      3
# 301  1.0    0   1    0        0       174     0      0.0    1    1      2
#
#      output  chol_bps
# 0         1       3.0
# 1         1       3.0
# 2         1       2.0
# 3         1       1.0
# 4         1       2.0
# ..      ...       ...
# 297       0       4.0
# 298       0       2.0
# 299       0       2.0
# 300       0       1.0
# 301       0       2.0
#
# [302 rows x 13 columns]

# %%
# data agumentation
new_df = df.copy()
def get_data(data):
    gen_data = data
    for restecg_values in data['restecg'].unique():
        new_data = gen_data[gen_data['restecg']== restecg_values]
        thalachh_std = new_data['thalachh'].std()
        oldpeak_std = new_data['oldpeak'].std()

        for i in gen_data[gen_data['restecg']== restecg_values].index:
            if np.random.randint(2)==1:
                gen_data['thalachh'].values[i] += thalachh_std/10   
            else:
                gen_data['thalachh'].values[i] -= thalachh_std/10
            if np.random.randint(2)==1:
                gen_data['oldpeak'].values[i] += oldpeak_std/10
            else:
                gen_data['oldpeak'].values[i] -= oldpeak_std/10
    return gen_data
print(df.head())  
std_data = get_data(new_df)
std_data.head()
# Out:
#    age  sex  cp  fbs  restecg  thalachh  exng  oldpeak  slp  caa  thall  \
# 0  1.0    1   3    1        0       150     0      2.3    0    0      1
# 1  0.0    1   2    0        1       187     0      3.5    0    0      2
# 2  0.0    0   1    0        0       172     0      1.4    2    0      2
# 3  1.0    1   1    0        1       178     0      0.8    2    0      2
# 4  1.0    0   0    0        1       163     1      0.6    2    0      2
#
#    output  chol_bps
# 0       1       3.0
# 1       1       3.0
# 2       1       2.0
# 3       1       1.0
# 4       1       2.0
#    age  sex  cp  fbs  restecg  thalachh  exng   oldpeak  slp  caa  thall  \
# 0  1.0    1   3    1        0       152     0  2.178532    0    0      1
# 1  0.0    1   2    0        1       189     0  3.394439    0    0      2
# 2  0.0    0   1    0        0       174     0  1.521468    2    0      2
# 3  1.0    1   1    0        1       175     0  0.905561    2    0      2
# 4  1.0    0   0    0        1       165     1  0.494439    2    0      2
#
#    output  chol_bps
# 0       1       3.0
# 1       1       3.0
# 2       1       2.0
# 3       1       1.0
# 4       1       2.0

# %%
x= df.drop(['output'], axis=1)
y = df.output
cat_fe = [ 'sex','cp','fbs','restecg','exng','slp','caa','thall','age']
num_fe = ['thalachh','oldpeak','chol_bps']

x_train, x_test, y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=0, stratify=y)

extra_sample = std_data.sample(std_data.shape[0]//3)
x_train = pd.concat([x_train, extra_sample.drop(['output'], axis=1)])
y_train = pd.concat([y_train, extra_sample['output']])

# %%
s_col = ['oldpeak', 'chol_bps']
scaler = MinMaxScaler()
for d in s_col:
    train_array = x_train[d].to_numpy()
    test_array = x_test[d].to_numpy()
    train_array = train_array.reshape(-1,1)
    test_array = test_array.reshape(-1,1)

    scaler.fit(train_array)
    x_train[d] = scaler.transform(train_array)
    x_test[d] = scaler.transform(test_array)

x_train.head()
# Out:
#      age  sex  cp  fbs  restecg  thalachh  exng   oldpeak  slp  caa  thall  \
# 268  1.0    1   0    1        0       103     1  0.300879    0    0      3
# 190  1.0    1   0    0        0       131     1  0.405747    1    3      3
# 15   0.0    0   2    0        1       158     0  0.300879    1    0      2
# 223  1.0    1   0    0        1       126     1  0.510615    1    1      3
# 249  0.0    1   0    0        1       122     1  0.755308    1    3      3
#
#      chol_bps
# 268      0.75
# 190      0.50
# 15       0.25
# 223      0.25
# 249      1.00

# %%
num_4_classifiers = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value=-9999))
])
cat_4_classifiers = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value=-9999))
])
classifier_prepro = ColumnTransformer(transformers=[
    ('num', num_4_classifiers, num_fe),
    ('cat',cat_4_classifiers, cat_fe)
], remainder='drop')

# %%
tree_classifiers = {
  "KNN": KNeighborsClassifier(),
  "svm": SVC(kernel='linear', C=2.0),
  "Logistic": LogisticRegression(C= 0.5, penalty= 'l1', solver= 'liblinear'),
  "Decision Tree": DecisionTreeClassifier(),
  "Extra Trees": ExtraTreesClassifier(n_estimators=100),
  "Random Forest": RandomForestClassifier(n_estimators=100),
  "AdaBoost": AdaBoostClassifier(n_estimators=100),
  "Skl GBM": GradientBoostingClassifier(n_estimators=100),
  "Skl HistGBM": HistGradientBoostingClassifier(max_iter=100),
  "XGBoost": XGBClassifier(n_estimators=100),
  "LightGBM": LGBMClassifier(n_estimators=100),
  "CatBoost":  CatBoostClassifier(depth= 9, iterations= 80, learning_rate= 0.04),
}
tree_classifiers= {name:make_pipeline(classifier_prepro, model) for name, model in tree_classifiers.items()}
tree_classifiers["AdaBoost"]
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value=-9999,
#                                                                                  strategy='constant'))]),
#                                                   ['thalachh', 'oldpeak',
#                                                    'chol_bps']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value=-9999,
#                                                                                  strategy='constant'))]),
#                                                   ['sex', 'cp', 'fbs',
#                                                    'restecg', 'exng', 'slp',
#                                                    'caa', 'thall', 'age'])])),
#                 ('adaboostclassifier', AdaBoostClassifier(n_estimators=100))])

# %%
results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})

for model_name, model in tree_classifiers.items():
    start_time = time.time()
    model.fit(x_train, y_train)
    total_time = time.time()-start_time
    pred = model.predict(x_test)
    results = results.append({"Model":    model_name,
                            "Accuracy": accuracy_score(y_test, pred)*100,
                            "Bal Acc.": balanced_accuracy_score(y_test, pred)*100,
                            "Time":     total_time},
                            ignore_index=True)

results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
results_ord.index += 1 
results_ord.style.bar(subset=['Accuracy', 'Bal Acc.'], vmin=0, vmax=100, color='#5fba7d')
# Out:
# /Users/felixschekerka/opt/anaconda3/envs/strive/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [07:35:53] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1645117948562/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0:	learn: 0.6834848	total: 54.5ms	remaining: 4.31s
# 1:	learn: 0.6741182	total: 55.8ms	remaining: 2.17s
# 2:	learn: 0.6626619	total: 57.1ms	remaining: 1.47s
# 3:	learn: 0.6532238	total: 58.1ms	remaining: 1.1s
# 4:	learn: 0.6457756	total: 60ms	remaining: 900ms
# 5:	learn: 0.6378859	total: 61.3ms	remaining: 756ms
# 6:	learn: 0.6289270	total: 62.6ms	remaining: 653ms
# 7:	learn: 0.6220203	total: 64ms	remaining: 576ms
# 8:	learn: 0.6156977	total: 65.7ms	remaining: 519ms
# 9:	learn: 0.6088227	total: 67.2ms	remaining: 470ms
# 10:	learn: 0.6004155	total: 68.5ms	remaining: 429ms
# 11:	learn: 0.5922462	total: 69.7ms	remaining: 395ms
# 12:	learn: 0.5836898	total: 71.1ms	remaining: 366ms
# 13:	learn: 0.5745324	total: 71.5ms	remaining: 337ms
# 14:	learn: 0.5637276	total: 72.1ms	remaining: 312ms
# 15:	learn: 0.5543219	total: 72.5ms	remaining: 290ms
# 16:	learn: 0.5480913	total: 74.1ms	remaining: 275ms
# 17:	learn: 0.5420255	total: 75.4ms	remaining: 260ms
# 18:	learn: 0.5350524	total: 76.7ms	remaining: 246ms
# 19:	learn: 0.5295905	total: 78ms	remaining: 234ms
# 20:	learn: 0.5227344	total: 78.6ms	remaining: 221ms
# 21:	learn: 0.5147786	total: 79.2ms	remaining: 209ms
# 22:	learn: 0.5104911	total: 80.5ms	remaining: 200ms
# 23:	learn: 0.5053431	total: 81.8ms	remaining: 191ms
# 24:	learn: 0.4996065	total: 82.7ms	remaining: 182ms
# 25:	learn: 0.4948419	total: 84.1ms	remaining: 175ms
# 26:	learn: 0.4903954	total: 85.6ms	remaining: 168ms
# 27:	learn: 0.4851392	total: 87.4ms	remaining: 162ms
# 28:	learn: 0.4802094	total: 89ms	remaining: 157ms
# 29:	learn: 0.4738122	total: 90ms	remaining: 150ms
# 30:	learn: 0.4695426	total: 91.3ms	remaining: 144ms
# 31:	learn: 0.4635715	total: 91.8ms	remaining: 138ms
# 32:	learn: 0.4597344	total: 93.2ms	remaining: 133ms
# 33:	learn: 0.4561097	total: 94.5ms	remaining: 128ms
# 34:	learn: 0.4499807	total: 95ms	remaining: 122ms
# 35:	learn: 0.4451314	total: 95.7ms	remaining: 117ms
# 36:	learn: 0.4418667	total: 97.2ms	remaining: 113ms
# 37:	learn: 0.4381714	total: 99ms	remaining: 109ms
# 38:	learn: 0.4345561	total: 101ms	remaining: 106ms
# 39:	learn: 0.4312781	total: 104ms	remaining: 104ms
# 40:	learn: 0.4271175	total: 105ms	remaining: 100ms
# 41:	learn: 0.4240162	total: 107ms	remaining: 97ms
# 42:	learn: 0.4202061	total: 109ms	remaining: 93.5ms
# 43:	learn: 0.4167743	total: 110ms	remaining: 90ms
# 44:	learn: 0.4136977	total: 111ms	remaining: 86.7ms
# 45:	learn: 0.4095459	total: 113ms	remaining: 83.5ms
# 46:	learn: 0.4068740	total: 114ms	remaining: 80.3ms
# 47:	learn: 0.4025502	total: 115ms	remaining: 76.7ms
# 48:	learn: 0.3995248	total: 117ms	remaining: 74ms
# 49:	learn: 0.3965521	total: 119ms	remaining: 71.2ms
# 50:	learn: 0.3921553	total: 119ms	remaining: 67.7ms
# 51:	learn: 0.3892439	total: 121ms	remaining: 65ms
# 52:	learn: 0.3852862	total: 121ms	remaining: 61.7ms
# 53:	learn: 0.3827188	total: 123ms	remaining: 59ms
# 54:	learn: 0.3793436	total: 124ms	remaining: 56.4ms
# 55:	learn: 0.3763298	total: 125ms	remaining: 53.8ms
# 56:	learn: 0.3740759	total: 127ms	remaining: 51.2ms
# 57:	learn: 0.3719156	total: 128ms	remaining: 48.6ms
# 58:	learn: 0.3694304	total: 130ms	remaining: 46.1ms
# 59:	learn: 0.3665655	total: 131ms	remaining: 43.8ms
# 60:	learn: 0.3639867	total: 133ms	remaining: 41.4ms
# 61:	learn: 0.3614542	total: 134ms	remaining: 39ms
# 62:	learn: 0.3591161	total: 136ms	remaining: 36.7ms
# 63:	learn: 0.3571731	total: 137ms	remaining: 34.3ms
# 64:	learn: 0.3549574	total: 139ms	remaining: 32ms
# 65:	learn: 0.3517548	total: 139ms	remaining: 29.6ms
# 66:	learn: 0.3493409	total: 141ms	remaining: 27.3ms
# 67:	learn: 0.3471418	total: 142ms	remaining: 25.1ms
# 68:	learn: 0.3446387	total: 143ms	remaining: 22.9ms
# 69:	learn: 0.3425019	total: 145ms	remaining: 20.7ms
# 70:	learn: 0.3400421	total: 147ms	remaining: 18.6ms
# 71:	learn: 0.3374155	total: 148ms	remaining: 16.5ms
# 72:	learn: 0.3349474	total: 149ms	remaining: 14.3ms
# 73:	learn: 0.3329027	total: 151ms	remaining: 12.2ms
# 74:	learn: 0.3308993	total: 152ms	remaining: 10.1ms
# 75:	learn: 0.3287236	total: 154ms	remaining: 8.09ms
# 76:	learn: 0.3271238	total: 155ms	remaining: 6.04ms
# 77:	learn: 0.3252117	total: 157ms	remaining: 4.01ms
# 78:	learn: 0.3232004	total: 158ms	remaining: 2ms
# 79:	learn: 0.3212828	total: 160ms	remaining: 0us
# <style type="text/css">
# #T_eae15_row0_col1, #T_eae15_row1_col1, #T_eae15_row2_col1, #T_eae15_row3_col1, #T_eae15_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 90.2%, transparent 90.2%);
# }
# #T_eae15_row0_col2, #T_eae15_row1_col2, #T_eae15_row2_col2, #T_eae15_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 90.1%, transparent 90.1%);
# }
# #T_eae15_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 89.8%, transparent 89.8%);
# }
# #T_eae15_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 88.5%, transparent 88.5%);
# }
# #T_eae15_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 88.6%, transparent 88.6%);
# }
# #T_eae15_row6_col1, #T_eae15_row7_col1, #T_eae15_row8_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 86.9%, transparent 86.9%);
# }
# #T_eae15_row6_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 86.3%, transparent 86.3%);
# }
# #T_eae15_row7_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 86.5%, transparent 86.5%);
# }
# #T_eae15_row8_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 86.8%, transparent 86.8%);
# }
# #T_eae15_row9_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 83.6%, transparent 83.6%);
# }
# #T_eae15_row9_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 83.2%, transparent 83.2%);
# }
# #T_eae15_row10_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 82.0%, transparent 82.0%);
# }
# #T_eae15_row10_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 81.2%, transparent 81.2%);
# }
# #T_eae15_row11_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 78.7%, transparent 78.7%);
# }
# #T_eae15_row11_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#5fba7d 78.4%, transparent 78.4%);
# }
# </style>
# <table id="T_eae15_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >Bal Acc.</th>
#       <th class="col_heading level0 col3" >Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eae15_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_eae15_row0_col0" class="data row0 col0" >Extra Trees</td>
#       <td id="T_eae15_row0_col1" class="data row0 col1" >90.163934</td>
#       <td id="T_eae15_row0_col2" class="data row0 col2" >90.097403</td>
#       <td id="T_eae15_row0_col3" class="data row0 col3" >0.149809</td>
#     </tr>
#     <tr>
#       <th id="T_eae15_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_eae15_row1_col0" class="data row1 col0" >Random Forest</td>
#       <td id="T_eae15_row1_col1" class="data row1 col1" >90.163934</td>
#       <td id="T_eae15_row1_col2" class="data row1 col2" >90.097403</td>
#       <td id="T_eae15_row1_col3" class="data row1 col3" >0.218209</td>
#     </tr>
#     <tr>
#       <th id="T_eae15_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_eae15_row2_col0" class="data row2 col0" >Skl HistGBM</td>
#       <td id="T_eae15_row2_col1" class="data row2 col1" >90.163934</td>
#       <td id="T_eae15_row2_col2" class="data row2 col2" >90.097403</td>
#       <td id="T_eae15_row2_col3" class="data row2 col3" >0.647371</td>
#     </tr>
#     <tr>
#       <th id="T_eae15_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_eae15_row3_col0" class="data row3 col0" >LightGBM</td>
#       <td id="T_eae15_row3_col1" class="data row3 col1" >90.163934</td>
#       <td id="T_eae15_row3_col2" class="data row3 col2" >90.097403</td>
#       <td id="T_eae15_row3_col3" class="data row3 col3" >0.037062</td>
#     </tr>
#     <tr>
#       <th id="T_eae15_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_eae15_row4_col0" class="data row4 col0" >CatBoost</td>
#       <td id="T_eae15_row4_col1" class="data row4 col1" >90.163934</td>
#       <td id="T_eae15_row4_col2" class="data row4 col2" >89.826840</td>
#       <td id="T_eae15_row4_col3" class="data row4 col3" >0.198256</td>
#     </tr>
#     <tr>
#       <th id="T_eae15_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_eae15_row5_col0" class="data row5 col0" >XGBoost</td>
#       <td id="T_eae15_row5_col1" class="data row5 col1" >88.524590</td>
#       <td id="T_eae15_row5_col2" class="data row5 col2" >88.582251</td>
#       <td id="T_eae15_row5_col3" class="data row5 col3" >0.342066</td>
#     </tr>
#     <tr>
#       <th id="T_eae15_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_eae15_row6_col0" class="data row6 col0" >svm</td>
#       <td id="T_eae15_row6_col1" class="data row6 col1" >86.885246</td>
#       <td id="T_eae15_row6_col2" class="data row6 col2" >86.255411</td>
#       <td id="T_eae15_row6_col3" class="data row6 col3" >0.239163</td>
#     </tr>
#     <tr>
#       <th id="T_eae15_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_eae15_row7_col0" class="data row7 col0" >Logistic</td>
#       <td id="T_eae15_row7_col1" class="data row7 col1" >86.885246</td>
#       <td id="T_eae15_row7_col2" class="data row7 col2" >86.525974</td>
#       <td id="T_eae15_row7_col3" class="data row7 col3" >0.019277</td>
#     </tr>
#     <tr>
#       <th id="T_eae15_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_eae15_row8_col0" class="data row8 col0" >Skl GBM</td>
#       <td id="T_eae15_row8_col1" class="data row8 col1" >86.885246</td>
#       <td id="T_eae15_row8_col2" class="data row8 col2" >86.796537</td>
#       <td id="T_eae15_row8_col3" class="data row8 col3" >0.098552</td>
#     </tr>
#     <tr>
#       <th id="T_eae15_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_eae15_row9_col0" class="data row9 col0" >Decision Tree</td>
#       <td id="T_eae15_row9_col1" class="data row9 col1" >83.606557</td>
#       <td id="T_eae15_row9_col2" class="data row9 col2" >83.225108</td>
#       <td id="T_eae15_row9_col3" class="data row9 col3" >0.014587</td>
#     </tr>
#     <tr>
#       <th id="T_eae15_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_eae15_row10_col0" class="data row10 col0" >KNN</td>
#       <td id="T_eae15_row10_col1" class="data row10 col1" >81.967213</td>
#       <td id="T_eae15_row10_col2" class="data row10 col2" >81.168831</td>
#       <td id="T_eae15_row10_col3" class="data row10 col3" >0.022654</td>
#     </tr>
#     <tr>
#       <th id="T_eae15_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_eae15_row11_col0" class="data row11 col0" >AdaBoost</td>
#       <td id="T_eae15_row11_col1" class="data row11 col1" >78.688525</td>
#       <td id="T_eae15_row11_col2" class="data row11 col2" >78.409091</td>
#       <td id="T_eae15_row11_col3" class="data row11 col3" >0.156087</td>
#     </tr>
#   </tbody>
# </table>
