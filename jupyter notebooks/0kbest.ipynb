# %%
# Import libraries
import os
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import register_matplotlib_converters  #Register pandas formatters and converters with matplotlib.
from pylab import rcParams      # for customizing matplotlib graphs.
sns.set_style("whitegrid")

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import accuracy_score, balanced_accuracy_score, plot_confusion_matrix
from sklearn import set_config
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline  
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import SelectKBest, chi2

# %%
from sklearn.tree          import DecisionTreeClassifier
from sklearn.ensemble      import RandomForestClassifier
from sklearn.ensemble      import ExtraTreesClassifier
from sklearn.ensemble      import AdaBoostClassifier
from sklearn.ensemble      import GradientBoostingClassifier
from sklearn.experimental  import enable_hist_gradient_boosting # Necesary for HistGradientBoostingClassifier
from sklearn.ensemble      import HistGradientBoostingClassifier
from xgboost               import XGBClassifier
from lightgbm              import LGBMClassifier
from catboost              import CatBoostClassifier
from sklearn.neighbors     import KNeighborsClassifier
from sklearn.linear_model  import LogisticRegression
from sklearn.svm           import SVC

# %%
df = pd.read_csv('heart.csv')
df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace = True)

# %%
#df.iloc[72]

# %%
## chainging numerical col 'chol' into categorical column:
df['chol']= pd.cut(df['chol'], bins=[0,200,239,564], labels = [0,1,2]) #0-High, 1-Borderline high, 2-High
df['trtbps']= pd.cut(df['trtbps'], bins=[90,120,139,200], labels = [0,1,2])
df['age'] = pd.cut(df['age'], bins=[25,53,80], labels = [0, 1])
df = df.astype({'trtbps':'float64','chol':'float64', 'age':'float64'})

# %%
df['chol_bps'] = df['chol']+df['trtbps']
df.drop(['chol','trtbps'], axis=1, inplace=True)
df
# Out:
#      age  sex  cp  fbs  restecg  thalachh  exng  oldpeak  slp  caa  thall  \
# 0    1.0    1   3    1        0       150     0      2.3    0    0      1
# 1    0.0    1   2    0        1       187     0      3.5    0    0      2
# 2    0.0    0   1    0        0       172     0      1.4    2    0      2
# 3    1.0    1   1    0        1       178     0      0.8    2    0      2
# 4    1.0    0   0    0        1       163     1      0.6    2    0      2
# ..   ...  ...  ..  ...      ...       ...   ...      ...  ...  ...    ...
# 297  1.0    0   0    0        1       123     1      0.2    1    0      3
# 298  0.0    1   3    0        1       132     0      1.2    1    0      3
# 299  1.0    1   0    1        1       141     0      3.4    1    2      3
# 300  1.0    1   0    0        1       115     1      1.2    1    1      3
# 301  1.0    0   1    0        0       174     0      0.0    1    1      2
#
#      output  chol_bps
# 0         1       3.0
# 1         1       3.0
# 2         1       2.0
# 3         1       1.0
# 4         1       2.0
# ..      ...       ...
# 297       0       4.0
# 298       0       2.0
# 299       0       2.0
# 300       0       1.0
# 301       0       2.0
#
# [302 rows x 13 columns]

# %%
rows_with_nan = [index for index, row in df.iterrows() if row.isnull().any()]

print(rows_with_nan)
# Out:
# []

# %%
# data agumentation
new_df = df.copy()
def get_data(data):
    gen_data = data
    for restecg_values in data['restecg'].unique():
        new_data = gen_data[gen_data['restecg']== restecg_values]
        thalachh_std = new_data['thalachh'].std()
        oldpeak_std = new_data['oldpeak'].std()

        for i in gen_data[gen_data['restecg']== restecg_values].index:
            if np.random.randint(2)==1:
                gen_data['thalachh'].values[i] += thalachh_std/10   
            else:
                gen_data['thalachh'].values[i] -= thalachh_std/10
            if np.random.randint(2)==1:
                gen_data['oldpeak'].values[i] += oldpeak_std/10
            else:
                gen_data['oldpeak'].values[i] -= oldpeak_std/10
    return gen_data
print(df.head())  
std_data = get_data(new_df)
std_data.head()
# Out:
#    age  sex  cp  fbs  restecg  thalachh  exng  oldpeak  slp  caa  thall  \
# 0  1.0    1   3    1        0       150     0      2.3    0    0      1
# 1  0.0    1   2    0        1       187     0      3.5    0    0      2
# 2  0.0    0   1    0        0       172     0      1.4    2    0      2
# 3  1.0    1   1    0        1       178     0      0.8    2    0      2
# 4  1.0    0   0    0        1       163     1      0.6    2    0      2
#
#    output  chol_bps
# 0       1       3.0
# 1       1       3.0
# 2       1       2.0
# 3       1       1.0
# 4       1       2.0
#    age  sex  cp  fbs  restecg  thalachh  exng   oldpeak  slp  caa  thall  \
# 0  1.0    1   3    1        0       152     0  2.421468    0    0      1
# 1  0.0    1   2    0        1       189     0  3.605561    0    0      2
# 2  0.0    0   1    0        0       169     0  1.521468    2    0      2
# 3  1.0    1   1    0        1       180     0  0.694439    2    0      2
# 4  1.0    0   0    0        1       160     1  0.705561    2    0      2
#
#    output  chol_bps
# 0       1       3.0
# 1       1       3.0
# 2       1       2.0
# 3       1       1.0
# 4       1       2.0

# %%
# x= df.drop(['output'], axis=1)
# y = df.output
# x_new = SelectKBest(chi2, k=8).fit_transform(x,y)
# print(x_new[0])
# print(x_new[1])
# print(x_new[2])

# %%
x= df.drop(['output'], axis=1)
y = df.output
cat_fe = [ 'age','cp','exng','slp','caa']
num_fe = ['thalachh','oldpeak','chol_bps']

x_train, x_test, y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=0, stratify=y)

extra_sample = std_data.sample(std_data.shape[0]//3)
x_train = pd.concat([x_train, extra_sample.drop(['output'], axis=1)])
y_train = pd.concat([y_train, extra_sample['output']])

# %%
s_col = ['oldpeak', 'chol_bps']
scaler = MinMaxScaler()
for d in s_col:
    train_array = x_train[d].to_numpy()
    test_array = x_test[d].to_numpy()
    train_array = train_array.reshape(-1,1)
    test_array = test_array.reshape(-1,1)

    scaler.fit(train_array)
    x_train[d] = scaler.transform(train_array)
    x_test[d] = scaler.transform(test_array)

x_train.head()
# Out:
# C:\Users\rnr31\AppData\Local\Temp\ipykernel_11004\866375025.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test[d] = scaler.transform(test_array)
# C:\Users\rnr31\AppData\Local\Temp\ipykernel_11004\866375025.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test[d] = scaler.transform(test_array)
#      age  sex  cp  fbs  restecg  thalachh  exng   oldpeak  slp  caa  thall  \
# 268  1.0    1   0    1        0       103     1  0.300879    0    0      3
# 190  1.0    1   0    0        0       131     1  0.405747    1    3      3
# 15   0.0    0   2    0        1       158     0  0.300879    1    0      2
# 223  1.0    1   0    0        1       126     1  0.510615    1    1      3
# 249  0.0    1   0    0        1       122     1  0.755308    1    3      3
#
#      chol_bps
# 268      0.75
# 190      0.50
# 15       0.25
# 223      0.25
# 249      1.00

# %%
num_4_classifiers = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value=-9999))
])
cat_4_classifiers = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value=-9999))
])
classifier_prepro = ColumnTransformer(transformers=[
    ('num', num_4_classifiers, num_fe),
    ('cat',cat_4_classifiers, cat_fe)
])

# %%
tree_classifiers = {
  "KNN": KNeighborsClassifier(),
  "svm": SVC(kernel='linear'),
  "Logistic": LogisticRegression(),
  "Decision Tree": DecisionTreeClassifier(),
  "Extra Trees": ExtraTreesClassifier(n_estimators=100),
  "Random Forest": RandomForestClassifier(n_estimators=100),
  "AdaBoost": AdaBoostClassifier(n_estimators=100),
  "Skl GBM": GradientBoostingClassifier(n_estimators=100),
  "Skl HistGBM": HistGradientBoostingClassifier(max_iter=100),
  "XGBoost": XGBClassifier(n_estimators=100),
  "LightGBM": LGBMClassifier(n_estimators=100),
  "CatBoost":  CatBoostClassifier(n_estimators=100),
}
tree_classifiers= {name:make_pipeline(classifier_prepro, model) for name, model in tree_classifiers.items()}
tree_classifiers["AdaBoost"]
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value=-9999,
#                                                                                  strategy='constant'))]),
#                                                   ['thalachh', 'oldpeak',
#                                                    'chol_bps']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value=-9999,
#                                                                                  strategy='constant'))]),
#                                                   ['age', 'cp', 'exng', 'slp',
#                                                    'caa'])])),
#                 ('adaboostclassifier', AdaBoostClassifier(n_estimators=100))])

# %%
### With out cross validation
results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})

for model_name, model in tree_classifiers.items():
    start_time = time.time()
    model.fit(x_train, y_train)
    total_time = time.time()-start_time
    pred = model.predict(x_test)
    results = results.append({"Model":    model_name,
                            "Accuracy": accuracy_score(y_test, pred)*100,
                            "Bal Acc.": balanced_accuracy_score(y_test, pred)*100,
                            "Time":     total_time},
                            ignore_index=True)

results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
results_ord.index += 1 
results_ord.style.bar(subset=['Accuracy', 'Bal Acc.'], vmin=0, vmax=100, color='#5fba7d')
# Out:
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [17:05:24] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Learning rate set to 0.053755
# 0:	learn: 0.6786045	total: 143ms	remaining: 14.2s
# 1:	learn: 0.6649951	total: 146ms	remaining: 7.15s
# 2:	learn: 0.6503591	total: 149ms	remaining: 4.82s
# 3:	learn: 0.6365908	total: 152ms	remaining: 3.64s
# 4:	learn: 0.6244249	total: 155ms	remaining: 2.95s
# 5:	learn: 0.6128625	total: 158ms	remaining: 2.48s
# 6:	learn: 0.6003449	total: 161ms	remaining: 2.14s
# 7:	learn: 0.5910654	total: 164ms	remaining: 1.89s
# 8:	learn: 0.5804197	total: 166ms	remaining: 1.68s
# 9:	learn: 0.5706946	total: 169ms	remaining: 1.52s
# 10:	learn: 0.5619353	total: 172ms	remaining: 1.39s
# 11:	learn: 0.5549551	total: 175ms	remaining: 1.28s
# 12:	learn: 0.5473013	total: 178ms	remaining: 1.19s
# 13:	learn: 0.5408124	total: 181ms	remaining: 1.11s
# 14:	learn: 0.5328687	total: 184ms	remaining: 1.04s
# 15:	learn: 0.5261978	total: 186ms	remaining: 978ms
# 16:	learn: 0.5193471	total: 188ms	remaining: 919ms
# 17:	learn: 0.5135265	total: 190ms	remaining: 866ms
# 18:	learn: 0.5068298	total: 192ms	remaining: 818ms
# 19:	learn: 0.5002871	total: 193ms	remaining: 772ms
# 20:	learn: 0.4948880	total: 194ms	remaining: 731ms
# 21:	learn: 0.4885270	total: 196ms	remaining: 695ms
# 22:	learn: 0.4841710	total: 198ms	remaining: 662ms
# 23:	learn: 0.4783955	total: 199ms	remaining: 630ms
# 24:	learn: 0.4728377	total: 200ms	remaining: 601ms
# 25:	learn: 0.4676154	total: 202ms	remaining: 574ms
# 26:	learn: 0.4633182	total: 203ms	remaining: 549ms
# 27:	learn: 0.4587434	total: 204ms	remaining: 525ms
# 28:	learn: 0.4539066	total: 206ms	remaining: 504ms
# 29:	learn: 0.4498709	total: 207ms	remaining: 482ms
# 30:	learn: 0.4452763	total: 208ms	remaining: 462ms
# 31:	learn: 0.4415957	total: 209ms	remaining: 443ms
# 32:	learn: 0.4377998	total: 210ms	remaining: 426ms
# 33:	learn: 0.4333837	total: 211ms	remaining: 409ms
# 34:	learn: 0.4292155	total: 212ms	remaining: 393ms
# 35:	learn: 0.4256898	total: 213ms	remaining: 378ms
# 36:	learn: 0.4221677	total: 213ms	remaining: 363ms
# 37:	learn: 0.4191310	total: 214ms	remaining: 349ms
# 38:	learn: 0.4161597	total: 215ms	remaining: 336ms
# 39:	learn: 0.4132502	total: 216ms	remaining: 324ms
# 40:	learn: 0.4106647	total: 217ms	remaining: 312ms
# 41:	learn: 0.4082177	total: 217ms	remaining: 300ms
# 42:	learn: 0.4058035	total: 218ms	remaining: 289ms
# 43:	learn: 0.4023972	total: 219ms	remaining: 279ms
# 44:	learn: 0.4006822	total: 220ms	remaining: 269ms
# 45:	learn: 0.3978753	total: 221ms	remaining: 259ms
# 46:	learn: 0.3953010	total: 221ms	remaining: 250ms
# 47:	learn: 0.3943692	total: 222ms	remaining: 240ms
# 48:	learn: 0.3920554	total: 222ms	remaining: 232ms
# 49:	learn: 0.3900308	total: 223ms	remaining: 223ms
# 50:	learn: 0.3882158	total: 225ms	remaining: 216ms
# 51:	learn: 0.3862609	total: 225ms	remaining: 208ms
# 52:	learn: 0.3835088	total: 226ms	remaining: 200ms
# 53:	learn: 0.3816058	total: 227ms	remaining: 193ms
# 54:	learn: 0.3791494	total: 227ms	remaining: 186ms
# 55:	learn: 0.3768215	total: 228ms	remaining: 179ms
# 56:	learn: 0.3748231	total: 229ms	remaining: 173ms
# 57:	learn: 0.3726771	total: 230ms	remaining: 166ms
# 58:	learn: 0.3704695	total: 230ms	remaining: 160ms
# 59:	learn: 0.3687289	total: 231ms	remaining: 154ms
# 60:	learn: 0.3662828	total: 232ms	remaining: 148ms
# 61:	learn: 0.3650005	total: 232ms	remaining: 142ms
# 62:	learn: 0.3628572	total: 233ms	remaining: 137ms
# 63:	learn: 0.3604807	total: 234ms	remaining: 132ms
# 64:	learn: 0.3590619	total: 235ms	remaining: 126ms
# 65:	learn: 0.3573423	total: 235ms	remaining: 121ms
# 66:	learn: 0.3551745	total: 236ms	remaining: 116ms
# 67:	learn: 0.3536518	total: 237ms	remaining: 111ms
# 68:	learn: 0.3515176	total: 237ms	remaining: 107ms
# 69:	learn: 0.3505638	total: 238ms	remaining: 102ms
# 70:	learn: 0.3494465	total: 239ms	remaining: 97.6ms
# 71:	learn: 0.3483198	total: 240ms	remaining: 93.2ms
# 72:	learn: 0.3473189	total: 240ms	remaining: 88.9ms
# 73:	learn: 0.3453496	total: 241ms	remaining: 84.6ms
# 74:	learn: 0.3438306	total: 242ms	remaining: 80.5ms
# 75:	learn: 0.3420796	total: 242ms	remaining: 76.5ms
# 76:	learn: 0.3406331	total: 243ms	remaining: 72.5ms
# 77:	learn: 0.3394863	total: 243ms	remaining: 68.7ms
# 78:	learn: 0.3381854	total: 244ms	remaining: 64.9ms
# 79:	learn: 0.3369642	total: 245ms	remaining: 61.2ms
# 80:	learn: 0.3357231	total: 245ms	remaining: 57.6ms
# 81:	learn: 0.3338954	total: 246ms	remaining: 54ms
# 82:	learn: 0.3324337	total: 247ms	remaining: 50.6ms
# 83:	learn: 0.3315708	total: 247ms	remaining: 47.1ms
# 84:	learn: 0.3299425	total: 248ms	remaining: 43.8ms
# 85:	learn: 0.3282696	total: 249ms	remaining: 40.5ms
# 86:	learn: 0.3271232	total: 250ms	remaining: 37.3ms
# 87:	learn: 0.3262997	total: 250ms	remaining: 34.1ms
# 88:	learn: 0.3252246	total: 251ms	remaining: 31ms
# 89:	learn: 0.3244417	total: 252ms	remaining: 28ms
# 90:	learn: 0.3234754	total: 252ms	remaining: 25ms
# 91:	learn: 0.3220680	total: 253ms	remaining: 22ms
# 92:	learn: 0.3206232	total: 254ms	remaining: 19.1ms
# 93:	learn: 0.3196053	total: 254ms	remaining: 16.2ms
# 94:	learn: 0.3183062	total: 255ms	remaining: 13.4ms
# 95:	learn: 0.3173953	total: 256ms	remaining: 10.7ms
# 96:	learn: 0.3162243	total: 257ms	remaining: 7.94ms
# 97:	learn: 0.3150135	total: 257ms	remaining: 5.25ms
# 98:	learn: 0.3139777	total: 258ms	remaining: 2.61ms
# 99:	learn: 0.3126789	total: 259ms	remaining: 0us
# <style  type="text/css" >
# #T_8d71eb7c_a867_11ec_8f74_48a472d2776erow0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 90.2%, transparent 90.2%);
#         }#T_8d71eb7c_a867_11ec_8f74_48a472d2776erow0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 89.8%, transparent 89.8%);
#         }#T_8d71eb7c_a867_11ec_8f74_48a472d2776erow1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 86.9%, transparent 86.9%);
#         }#T_8d71eb7c_a867_11ec_8f74_48a472d2776erow1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 86.3%, transparent 86.3%);
#         }#T_8d71eb7c_a867_11ec_8f74_48a472d2776erow2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 85.2%, transparent 85.2%);
#         }#T_8d71eb7c_a867_11ec_8f74_48a472d2776erow2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 84.5%, transparent 84.5%);
#         }#T_8d71eb7c_a867_11ec_8f74_48a472d2776erow3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 82.0%, transparent 82.0%);
#         }#T_8d71eb7c_a867_11ec_8f74_48a472d2776erow3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 81.4%, transparent 81.4%);
#         }#T_8d71eb7c_a867_11ec_8f74_48a472d2776erow4_col1,#T_8d71eb7c_a867_11ec_8f74_48a472d2776erow5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 80.3%, transparent 80.3%);
#         }#T_8d71eb7c_a867_11ec_8f74_48a472d2776erow4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 80.5%, transparent 80.5%);
#         }#T_8d71eb7c_a867_11ec_8f74_48a472d2776erow5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 79.7%, transparent 79.7%);
#         }#T_8d71eb7c_a867_11ec_8f74_48a472d2776erow6_col1,#T_8d71eb7c_a867_11ec_8f74_48a472d2776erow6_col2,#T_8d71eb7c_a867_11ec_8f74_48a472d2776erow7_col1,#T_8d71eb7c_a867_11ec_8f74_48a472d2776erow7_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 78.7%, transparent 78.7%);
#         }#T_8d71eb7c_a867_11ec_8f74_48a472d2776erow8_col1,#T_8d71eb7c_a867_11ec_8f74_48a472d2776erow9_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 77.0%, transparent 77.0%);
#         }#T_8d71eb7c_a867_11ec_8f74_48a472d2776erow8_col2,#T_8d71eb7c_a867_11ec_8f74_48a472d2776erow9_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 76.6%, transparent 76.6%);
#         }#T_8d71eb7c_a867_11ec_8f74_48a472d2776erow10_col1,#T_8d71eb7c_a867_11ec_8f74_48a472d2776erow11_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 75.4%, transparent 75.4%);
#         }#T_8d71eb7c_a867_11ec_8f74_48a472d2776erow10_col2,#T_8d71eb7c_a867_11ec_8f74_48a472d2776erow11_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 75.1%, transparent 75.1%);
#         }</style><table id="T_8d71eb7c_a867_11ec_8f74_48a472d2776e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >Bal Acc.</th>        <th class="col_heading level0 col3" >Time</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8d71eb7c_a867_11ec_8f74_48a472d2776elevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_8d71eb7c_a867_11ec_8f74_48a472d2776erow0_col0" class="data row0 col0" >Extra Trees</td>
#                         <td id="T_8d71eb7c_a867_11ec_8f74_48a472d2776erow0_col1" class="data row0 col1" >90.163934</td>
#                         <td id="T_8d71eb7c_a867_11ec_8f74_48a472d2776erow0_col2" class="data row0 col2" >89.826840</td>
#                         <td id="T_8d71eb7c_a867_11ec_8f74_48a472d2776erow0_col3" class="data row0 col3" >0.186501</td>
#             </tr>
#             <tr>
#                         <th id="T_8d71eb7c_a867_11ec_8f74_48a472d2776elevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_8d71eb7c_a867_11ec_8f74_48a472d2776erow1_col0" class="data row1 col0" >Random Forest</td>
#                         <td id="T_8d71eb7c_a867_11ec_8f74_48a472d2776erow1_col1" class="data row1 col1" >86.885246</td>
#                         <td id="T_8d71eb7c_a867_11ec_8f74_48a472d2776erow1_col2" class="data row1 col2" >86.255411</td>
#                         <td id="T_8d71eb7c_a867_11ec_8f74_48a472d2776erow1_col3" class="data row1 col3" >0.151595</td>
#             </tr>
#             <tr>
#                         <th id="T_8d71eb7c_a867_11ec_8f74_48a472d2776elevel0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_8d71eb7c_a867_11ec_8f74_48a472d2776erow2_col0" class="data row2 col0" >CatBoost</td>
#                         <td id="T_8d71eb7c_a867_11ec_8f74_48a472d2776erow2_col1" class="data row2 col1" >85.245902</td>
#                         <td id="T_8d71eb7c_a867_11ec_8f74_48a472d2776erow2_col2" class="data row2 col2" >84.469697</td>
#                         <td id="T_8d71eb7c_a867_11ec_8f74_48a472d2776erow2_col3" class="data row2 col3" >0.362110</td>
#             </tr>
#             <tr>
#                         <th id="T_8d71eb7c_a867_11ec_8f74_48a472d2776elevel0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_8d71eb7c_a867_11ec_8f74_48a472d2776erow3_col0" class="data row3 col0" >Skl HistGBM</td>
#                         <td id="T_8d71eb7c_a867_11ec_8f74_48a472d2776erow3_col1" class="data row3 col1" >81.967213</td>
#                         <td id="T_8d71eb7c_a867_11ec_8f74_48a472d2776erow3_col2" class="data row3 col2" >81.439394</td>
#                         <td id="T_8d71eb7c_a867_11ec_8f74_48a472d2776erow3_col3" class="data row3 col3" >0.348037</td>
#             </tr>
#             <tr>
#                         <th id="T_8d71eb7c_a867_11ec_8f74_48a472d2776elevel0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_8d71eb7c_a867_11ec_8f74_48a472d2776erow4_col0" class="data row4 col0" >Decision Tree</td>
#                         <td id="T_8d71eb7c_a867_11ec_8f74_48a472d2776erow4_col1" class="data row4 col1" >80.327869</td>
#                         <td id="T_8d71eb7c_a867_11ec_8f74_48a472d2776erow4_col2" class="data row4 col2" >80.465368</td>
#                         <td id="T_8d71eb7c_a867_11ec_8f74_48a472d2776erow4_col3" class="data row4 col3" >0.012965</td>
#             </tr>
#             <tr>
#                         <th id="T_8d71eb7c_a867_11ec_8f74_48a472d2776elevel0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_8d71eb7c_a867_11ec_8f74_48a472d2776erow5_col0" class="data row5 col0" >LightGBM</td>
#                         <td id="T_8d71eb7c_a867_11ec_8f74_48a472d2776erow5_col1" class="data row5 col1" >80.327869</td>
#                         <td id="T_8d71eb7c_a867_11ec_8f74_48a472d2776erow5_col2" class="data row5 col2" >79.653680</td>
#                         <td id="T_8d71eb7c_a867_11ec_8f74_48a472d2776erow5_col3" class="data row5 col3" >0.078790</td>
#             </tr>
#             <tr>
#                         <th id="T_8d71eb7c_a867_11ec_8f74_48a472d2776elevel0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_8d71eb7c_a867_11ec_8f74_48a472d2776erow6_col0" class="data row6 col0" >Skl GBM</td>

# %%
# skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)

# results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})

# for model_name, model in tree_classifiers.items():
#     start_time = time.time()
        
#     # TRAIN AND GET PREDICTIONS USING cross_val_predict() and x,y
#     pred = cross_val_predict(model, x_train,y_train, cv=skf)

#     total_time = time.time() - start_time

#     results = results.append({"Model":    model_name,
#                               "Accuracy": accuracy_score(y_train, pred)*100,
#                               "Bal Acc.": balanced_accuracy_score(y_train, pred)*100,
#                               "Time":     total_time},
#                               ignore_index=True)
                              
                              
# results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
# results_ord.index += 1 
# results_ord.style.bar(subset=['Accuracy','Bal Acc.'], vmin=0, vmax=100, color='#5fba7d')
