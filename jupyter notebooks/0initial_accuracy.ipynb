# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
x = df.drop(['output'], axis=1)
y = df.output
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: output, dtype: int64

# %%
from sklearn.tree          import DecisionTreeClassifier
from sklearn.ensemble      import RandomForestClassifier
from sklearn.ensemble      import ExtraTreesClassifier
from sklearn.ensemble      import AdaBoostClassifier
from sklearn.ensemble      import GradientBoostingClassifier
from sklearn.experimental  import enable_hist_gradient_boosting # Necesary for HistGradientBoostingClassifier
from sklearn.ensemble      import HistGradientBoostingClassifier
from xgboost               import XGBClassifier
from lightgbm              import LGBMClassifier
from catboost              import CatBoostClassifier
from sklearn.neighbors     import KNeighborsClassifier
from sklearn.linear_model  import LogisticRegression
from sklearn.svm           import SVC

# %%
tree_classifiers = {
  "KNN": KNeighborsClassifier(),
  "svm": SVC(kernel='linear'),
  "Logistic": LogisticRegression(),
  "Decision Tree": DecisionTreeClassifier(),
  "Extra Trees": ExtraTreesClassifier(n_estimators=100),
  "Random Forest": RandomForestClassifier(n_estimators=100),
  "AdaBoost": AdaBoostClassifier(n_estimators=100),
  "Skl GBM": GradientBoostingClassifier(n_estimators=100),
  "Skl HistGBM": HistGradientBoostingClassifier(max_iter=100),
  "XGBoost": XGBClassifier(n_estimators=100),
  "LightGBM": LGBMClassifier(n_estimators=100),
  "CatBoost":  CatBoostClassifier(n_estimators=100),
}

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, balanced_accuracy_score
import time
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_predict

# %%
x_train, x_val, y_train, y_val = train_test_split(x,y, test_size=0.2, random_state=0, stratify=y)

results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})

for model_name, model in tree_classifiers.items():
    start_time = time.time()
    
    # FOR EVERY PIPELINE (PREPRO + MODEL) -> TRAIN WITH TRAIN DATA (x_train)
    model.fit(x_train, y_train)
    
    # GET PREDICTIONS USING x_val
    pred = model.predict(x_val)

    total_time = time.time() - start_time

    results = results.append({"Model":    model_name,
                              "Accuracy": accuracy_score(y_val, pred)*100,
                              "Bal Acc.": balanced_accuracy_score(y_val, pred)*100,
                              "Time":     total_time},
                              ignore_index=True)
                              
                              
results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
results_ord.index += 1 
results_ord.style.bar(subset=['Accuracy', 'Bal Acc.'], vmin=0, vmax=100, color='#5fba7d')
# Out:
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:28:36] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Learning rate set to 0.046433
# 0:	learn: 0.6790821	total: 158ms	remaining: 15.7s
# 1:	learn: 0.6657594	total: 162ms	remaining: 7.93s
# 2:	learn: 0.6543576	total: 165ms	remaining: 5.33s
# 3:	learn: 0.6444219	total: 169ms	remaining: 4.06s
# 4:	learn: 0.6329162	total: 173ms	remaining: 3.29s
# 5:	learn: 0.6221862	total: 177ms	remaining: 2.77s
# 6:	learn: 0.6107582	total: 181ms	remaining: 2.4s
# 7:	learn: 0.6009203	total: 185ms	remaining: 2.13s
# 8:	learn: 0.5915528	total: 189ms	remaining: 1.91s
# 9:	learn: 0.5844890	total: 193ms	remaining: 1.73s
# 10:	learn: 0.5774758	total: 196ms	remaining: 1.58s
# 11:	learn: 0.5699803	total: 202ms	remaining: 1.48s
# 12:	learn: 0.5634174	total: 204ms	remaining: 1.36s
# 13:	learn: 0.5535252	total: 205ms	remaining: 1.26s
# 14:	learn: 0.5457229	total: 207ms	remaining: 1.17s
# 15:	learn: 0.5388175	total: 209ms	remaining: 1.09s
# 16:	learn: 0.5319404	total: 210ms	remaining: 1.03s
# 17:	learn: 0.5259541	total: 212ms	remaining: 967ms
# 18:	learn: 0.5191738	total: 214ms	remaining: 911ms
# 19:	learn: 0.5114243	total: 214ms	remaining: 858ms
# 20:	learn: 0.5059065	total: 216ms	remaining: 812ms
# 21:	learn: 0.4992770	total: 217ms	remaining: 770ms
# 22:	learn: 0.4947407	total: 218ms	remaining: 731ms
# 23:	learn: 0.4895672	total: 219ms	remaining: 695ms
# 24:	learn: 0.4847573	total: 221ms	remaining: 662ms
# 25:	learn: 0.4791511	total: 222ms	remaining: 631ms
# 26:	learn: 0.4736776	total: 223ms	remaining: 603ms
# 27:	learn: 0.4680065	total: 224ms	remaining: 576ms
# 28:	learn: 0.4647171	total: 225ms	remaining: 550ms
# 29:	learn: 0.4599101	total: 226ms	remaining: 528ms
# 30:	learn: 0.4565034	total: 227ms	remaining: 506ms
# 31:	learn: 0.4514407	total: 228ms	remaining: 485ms
# 32:	learn: 0.4469668	total: 229ms	remaining: 465ms
# 33:	learn: 0.4425512	total: 230ms	remaining: 447ms
# 34:	learn: 0.4385742	total: 231ms	remaining: 429ms
# 35:	learn: 0.4347713	total: 232ms	remaining: 412ms
# 90:	learn: 0.3082372	total: 281ms	remaining: 27.8ms
# 91:	learn: 0.3066811	total: 282ms	remaining: 24.5ms
# 92:	learn: 0.3046952	total: 282ms	remaining: 21.3ms
# 93:	learn: 0.3030681	total: 283ms	remaining: 18.1ms
# 94:	learn: 0.3018113	total: 284ms	remaining: 14.9ms
# 95:	learn: 0.3002145	total: 285ms	remaining: 11.9ms
# 96:	learn: 0.2984009	total: 285ms	remaining: 8.82ms
# 97:	learn: 0.2973169	total: 286ms	remaining: 5.83ms
# 98:	learn: 0.2956048	total: 286ms	remaining: 2.89ms
# 99:	learn: 0.2945707	total: 287ms	remaining: 0us
# <style  type="text/css" >
# #T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow0_col1,#T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 88.5%, transparent 88.5%);
#         }#T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 88.3%, transparent 88.3%);
#         }#T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 88.0%, transparent 88.0%);
#         }#T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow2_col1,#T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 86.9%, transparent 86.9%);
#         }#T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 86.3%, transparent 86.3%);
#         }#T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 86.5%, transparent 86.5%);
#         }#T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 85.2%, transparent 85.2%);
#         }#T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 85.0%, transparent 85.0%);
#         }#T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 83.6%, transparent 83.6%);
#         }#T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 83.5%, transparent 83.5%);
#         }#T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 82.0%, transparent 82.0%);
#         }#T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow6_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 81.7%, transparent 81.7%);
#         }#T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow7_col1,#T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 80.3%, transparent 80.3%);
#         }#T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow7_col2,#T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow8_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 79.9%, transparent 79.9%);
#         }#T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow9_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 78.7%, transparent 78.7%);
#         }#T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow9_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 78.1%, transparent 78.1%);
#         }#T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow10_col1,#T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow10_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 75.4%, transparent 75.4%);
#         }#T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow11_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 70.5%, transparent 70.5%);
#         }#T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow11_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 70.3%, transparent 70.3%);
#         }</style><table id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >Bal Acc.</th>        <th class="col_heading level0 col3" >Time</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776elevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow0_col0" class="data row0 col0" >Logistic</td>
#                         <td id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow0_col1" class="data row0 col1" >88.524590</td>
#                         <td id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow0_col2" class="data row0 col2" >88.311688</td>
#                         <td id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow0_col3" class="data row0 col3" >0.027494</td>
#             </tr>
#             <tr>
#                         <th id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776elevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow1_col0" class="data row1 col0" >CatBoost</td>
#                         <td id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow1_col1" class="data row1 col1" >88.524590</td>
#                         <td id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow1_col2" class="data row1 col2" >88.041126</td>
#                         <td id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow1_col3" class="data row1 col3" >0.587404</td>
#             </tr>
#             <tr>
#                         <th id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776elevel0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow2_col0" class="data row2 col0" >svm</td>
#                         <td id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow2_col1" class="data row2 col1" >86.885246</td>
#                         <td id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow2_col2" class="data row2 col2" >86.255411</td>
#                         <td id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow2_col3" class="data row2 col3" >0.290020</td>
#             </tr>
#             <tr>
#                         <th id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776elevel0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow3_col0" class="data row3 col0" >XGBoost</td>
#                         <td id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow3_col1" class="data row3 col1" >86.885246</td>
#                         <td id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow3_col2" class="data row3 col2" >86.525974</td>
#                         <td id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow3_col3" class="data row3 col3" >0.111017</td>
#             </tr>
#             <tr>
#                         <th id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776elevel0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow4_col0" class="data row4 col0" >Skl GBM</td>
#                         <td id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow4_col1" class="data row4 col1" >85.245902</td>
#                         <td id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow4_col2" class="data row4 col2" >85.010823</td>
#                         <td id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow4_col3" class="data row4 col3" >0.090207</td>
#             </tr>
#             <tr>
#                         <th id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776elevel0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow5_col0" class="data row5 col0" >Random Forest</td>
#                         <td id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow5_col1" class="data row5 col1" >83.606557</td>
#                         <td id="T_8f8ad4c4_a87b_11ec_9e12_48a472d2776erow5_col2" class="data row5 col2" >83.495671

# %%
# skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)

# results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})

# for model_name, model in tree_classifiers.items():
#     start_time = time.time()
        
#     # TRAIN AND GET PREDICTIONS USING cross_val_predict() and x,y
#     pred = cross_val_predict(model, x,y, cv=skf)

#     total_time = time.time() - start_time

#     results = results.append({"Model":    model_name,
#                               "Accuracy": accuracy_score(y, pred)*100,
#                               "Bal Acc.": balanced_accuracy_score(y, pred)*100,
#                               "Time":     total_time},
#                               ignore_index=True)
                              
                              
# results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
# results_ord.index += 1 
# results_ord.style.bar(subset=['Accuracy','Bal Acc.'], vmin=0, vmax=100, color='#5fba7d')
