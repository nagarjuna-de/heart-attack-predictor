# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
x = df.drop(['output'], axis=1)
y = df.output
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: output, dtype: int64

# %%
from sklearn.tree          import DecisionTreeClassifier
from sklearn.ensemble      import RandomForestClassifier
from sklearn.ensemble      import ExtraTreesClassifier
from sklearn.ensemble      import AdaBoostClassifier
from sklearn.ensemble      import GradientBoostingClassifier
from sklearn.experimental  import enable_hist_gradient_boosting # Necesary for HistGradientBoostingClassifier
from sklearn.ensemble      import HistGradientBoostingClassifier
from xgboost               import XGBClassifier
from lightgbm              import LGBMClassifier
from catboost              import CatBoostClassifier
from sklearn.neighbors     import KNeighborsClassifier
from sklearn.linear_model  import LogisticRegression
from sklearn.svm           import SVC

# %%
tree_classifiers = {
  "KNN": KNeighborsClassifier(),
  "svm": SVC(kernel='linear'),
  "Logistic": LogisticRegression(),
  "Decision Tree": DecisionTreeClassifier(),
  "Extra Trees": ExtraTreesClassifier(n_estimators=100),
  "Random Forest": RandomForestClassifier(n_estimators=100),
  "AdaBoost": AdaBoostClassifier(n_estimators=100),
  "Skl GBM": GradientBoostingClassifier(n_estimators=100),
  "Skl HistGBM": HistGradientBoostingClassifier(max_iter=100),
  "XGBoost": XGBClassifier(n_estimators=100),
  "LightGBM": LGBMClassifier(n_estimators=100),
  "CatBoost":  CatBoostClassifier(n_estimators=100),
}

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, balanced_accuracy_score
import time
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_predict

# %%
x_train, x_val, y_train, y_val = train_test_split(x,y, test_size=0.2, random_state=0, stratify=y)

results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})

for model_name, model in tree_classifiers.items():
    start_time = time.time()
    
    # FOR EVERY PIPELINE (PREPRO + MODEL) -> TRAIN WITH TRAIN DATA (x_train)
    model.fit(x_train, y_train)
    
    # GET PREDICTIONS USING x_val
    pred = model.predict(x_val)

    total_time = time.time() - start_time

    results = results.append({"Model":    model_name,
                              "Accuracy": accuracy_score(y_val, pred)*100,
                              "Bal Acc.": balanced_accuracy_score(y_val, pred)*100,
                              "Time":     total_time},
                              ignore_index=True)
                              
                              
results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
results_ord.index += 1 
results_ord.style.bar(subset=['Accuracy', 'Bal Acc.'], vmin=0, vmax=100, color='#5fba7d')
# Out:
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:51:01] WARNING: D:\bld\xgboost-split_1645118015404\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Learning rate set to 0.046433
# 0:	learn: 0.6790821	total: 147ms	remaining: 14.6s
# 1:	learn: 0.6657594	total: 148ms	remaining: 7.26s
# 2:	learn: 0.6543576	total: 149ms	remaining: 4.82s
# 3:	learn: 0.6444219	total: 150ms	remaining: 3.6s
# 4:	learn: 0.6329162	total: 151ms	remaining: 2.87s
# 5:	learn: 0.6221862	total: 152ms	remaining: 2.38s
# 6:	learn: 0.6107582	total: 153ms	remaining: 2.03s
# 7:	learn: 0.6009203	total: 154ms	remaining: 1.77s
# 8:	learn: 0.5915528	total: 155ms	remaining: 1.56s
# 9:	learn: 0.5844890	total: 156ms	remaining: 1.4s
# 10:	learn: 0.5774758	total: 157ms	remaining: 1.27s
# 11:	learn: 0.5699803	total: 158ms	remaining: 1.16s
# 12:	learn: 0.5634174	total: 158ms	remaining: 1.06s
# 13:	learn: 0.5535252	total: 159ms	remaining: 976ms
# 14:	learn: 0.5457229	total: 160ms	remaining: 906ms
# 15:	learn: 0.5388175	total: 161ms	remaining: 843ms
# 16:	learn: 0.5319404	total: 161ms	remaining: 788ms
# 17:	learn: 0.5259541	total: 162ms	remaining: 738ms
# 18:	learn: 0.5191738	total: 163ms	remaining: 697ms
# 19:	learn: 0.5114243	total: 164ms	remaining: 656ms
# 20:	learn: 0.5059065	total: 165ms	remaining: 621ms
# 21:	learn: 0.4992770	total: 166ms	remaining: 589ms
# 22:	learn: 0.4947407	total: 167ms	remaining: 559ms
# 23:	learn: 0.4895672	total: 168ms	remaining: 531ms
# 24:	learn: 0.4847573	total: 169ms	remaining: 507ms
# 25:	learn: 0.4791511	total: 170ms	remaining: 484ms
# 26:	learn: 0.4736776	total: 171ms	remaining: 462ms
# 27:	learn: 0.4680065	total: 172ms	remaining: 442ms
# 28:	learn: 0.4647171	total: 172ms	remaining: 422ms
# 75:	learn: 0.3309136	total: 214ms	remaining: 67.6ms
# 76:	learn: 0.3297075	total: 215ms	remaining: 64.1ms
# 77:	learn: 0.3279630	total: 216ms	remaining: 60.8ms
# 78:	learn: 0.3263955	total: 216ms	remaining: 57.5ms
# 79:	learn: 0.3248722	total: 217ms	remaining: 54.3ms
# 80:	learn: 0.3235120	total: 218ms	remaining: 51.1ms
# 81:	learn: 0.3221633	total: 219ms	remaining: 48ms
# 82:	learn: 0.3205363	total: 219ms	remaining: 44.9ms
# 83:	learn: 0.3183704	total: 220ms	remaining: 42ms
# 84:	learn: 0.3170876	total: 221ms	remaining: 39ms
# 85:	learn: 0.3154153	total: 222ms	remaining: 36.1ms
# 86:	learn: 0.3138762	total: 223ms	remaining: 33.3ms
# 87:	learn: 0.3121864	total: 223ms	remaining: 30.5ms
# 88:	learn: 0.3106720	total: 224ms	remaining: 27.7ms
# 89:	learn: 0.3092569	total: 226ms	remaining: 25.1ms
# 90:	learn: 0.3082372	total: 227ms	remaining: 22.4ms
# 91:	learn: 0.3066811	total: 227ms	remaining: 19.8ms
# 92:	learn: 0.3046952	total: 228ms	remaining: 17.2ms
# 93:	learn: 0.3030681	total: 229ms	remaining: 14.6ms
# 94:	learn: 0.3018113	total: 230ms	remaining: 12.1ms
# 95:	learn: 0.3002145	total: 231ms	remaining: 9.61ms
# 96:	learn: 0.2984009	total: 231ms	remaining: 7.15ms
# 97:	learn: 0.2973169	total: 232ms	remaining: 4.73ms
# 98:	learn: 0.2956048	total: 232ms	remaining: 2.35ms
# 99:	learn: 0.2945707	total: 233ms	remaining: 0us
# <style  type="text/css" >
# #T_8cb7131a_a865_11ec_8c18_48a472d2776erow0_col1,#T_8cb7131a_a865_11ec_8c18_48a472d2776erow1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 88.5%, transparent 88.5%);
#         }#T_8cb7131a_a865_11ec_8c18_48a472d2776erow0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 88.3%, transparent 88.3%);
#         }#T_8cb7131a_a865_11ec_8c18_48a472d2776erow1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 88.0%, transparent 88.0%);
#         }#T_8cb7131a_a865_11ec_8c18_48a472d2776erow2_col1,#T_8cb7131a_a865_11ec_8c18_48a472d2776erow3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 86.9%, transparent 86.9%);
#         }#T_8cb7131a_a865_11ec_8c18_48a472d2776erow2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 86.3%, transparent 86.3%);
#         }#T_8cb7131a_a865_11ec_8c18_48a472d2776erow3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 86.5%, transparent 86.5%);
#         }#T_8cb7131a_a865_11ec_8c18_48a472d2776erow4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 85.2%, transparent 85.2%);
#         }#T_8cb7131a_a865_11ec_8c18_48a472d2776erow4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 85.0%, transparent 85.0%);
#         }#T_8cb7131a_a865_11ec_8c18_48a472d2776erow5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 83.6%, transparent 83.6%);
#         }#T_8cb7131a_a865_11ec_8c18_48a472d2776erow5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 83.2%, transparent 83.2%);
#         }#T_8cb7131a_a865_11ec_8c18_48a472d2776erow6_col1,#T_8cb7131a_a865_11ec_8c18_48a472d2776erow7_col1,#T_8cb7131a_a865_11ec_8c18_48a472d2776erow8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 80.3%, transparent 80.3%);
#         }#T_8cb7131a_a865_11ec_8c18_48a472d2776erow6_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 80.2%, transparent 80.2%);
#         }#T_8cb7131a_a865_11ec_8c18_48a472d2776erow7_col2,#T_8cb7131a_a865_11ec_8c18_48a472d2776erow8_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 79.9%, transparent 79.9%);
#         }#T_8cb7131a_a865_11ec_8c18_48a472d2776erow9_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 78.7%, transparent 78.7%);
#         }#T_8cb7131a_a865_11ec_8c18_48a472d2776erow9_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 78.1%, transparent 78.1%);
#         }#T_8cb7131a_a865_11ec_8c18_48a472d2776erow10_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 77.0%, transparent 77.0%);
#         }#T_8cb7131a_a865_11ec_8c18_48a472d2776erow10_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 76.9%, transparent 76.9%);
#         }#T_8cb7131a_a865_11ec_8c18_48a472d2776erow11_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 70.5%, transparent 70.5%);
#         }#T_8cb7131a_a865_11ec_8c18_48a472d2776erow11_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 70.3%, transparent 70.3%);
#         }</style><table id="T_8cb7131a_a865_11ec_8c18_48a472d2776e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >Bal Acc.</th>        <th class="col_heading level0 col3" >Time</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8cb7131a_a865_11ec_8c18_48a472d2776elevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_8cb7131a_a865_11ec_8c18_48a472d2776erow0_col0" class="data row0 col0" >Logistic</td>
#                         <td id="T_8cb7131a_a865_11ec_8c18_48a472d2776erow0_col1" class="data row0 col1" >88.524590</td>
#                         <td id="T_8cb7131a_a865_11ec_8c18_48a472d2776erow0_col2" class="data row0 col2" >88.311688</td>
#                         <td id="T_8cb7131a_a865_11ec_8c18_48a472d2776erow0_col3" class="data row0 col3" >0.026976</td>
#             </tr>
#             <tr>
#                         <th id="T_8cb7131a_a865_11ec_8c18_48a472d2776elevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_8cb7131a_a865_11ec_8c18_48a472d2776erow1_col0" class="data row1 col0" >CatBoost</td>
#                         <td id="T_8cb7131a_a865_11ec_8c18_48a472d2776erow1_col1" class="data row1 col1" >88.524590</td>
#                         <td id="T_8cb7131a_a865_11ec_8c18_48a472d2776erow1_col2" class="data row1 col2" >88.041126</td>
#                         <td id="T_8cb7131a_a865_11ec_8c18_48a472d2776erow1_col3" class="data row1 col3" >2.597620</td>
#             </tr>
#             <tr>
#                         <th id="T_8cb7131a_a865_11ec_8c18_48a472d2776elevel0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_8cb7131a_a865_11ec_8c18_48a472d2776erow2_col0" class="data row2 col0" >svm</td>
#                         <td id="T_8cb7131a_a865_11ec_8c18_48a472d2776erow2_col1" class="data row2 col1" >86.885246</td>
#                         <td id="T_8cb7131a_a865_11ec_8c18_48a472d2776erow2_col2" class="data row2 col2" >86.255411</td>
#                         <td id="T_8cb7131a_a865_11ec_8c18_48a472d2776erow2_col3" class="data row2 col3" >0.305219</td>
#             </tr>
#             <tr>
#                         <th id="T_8cb7131a_a865_11ec_8c18_48a472d2776elevel0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_8cb7131a_a865_11ec_8c18_48a472d2776erow3_col0" class="data row3 col0" >XGBoost</td>
#                         <td id="T_8cb7131a_a865_11ec_8c18_48a472d2776erow3_col1" class="data row3 col1" >86.885246</td>
#                         <td id="T_8cb7131a_a865_11ec_8c18_48a472d2776erow3_col2" class="data row3 col2" >86.525974</td>
#                         <td id="T_8cb7131a_a865_11ec_8c18_48a472d2776erow3_col3" class="data row3 col3" >0.100731</td>
#             </tr>
#             <tr>
#                         <th id="T_8cb7131a_a865_11ec_8c18_48a472d2776elevel0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_8cb7131a_a865_11ec_8c18_48a472d2776erow4_col0" class="data row4 col0" >Skl GBM</td>
#                         <td id="T_8cb7131a_a865_11ec_8c18_48a472d2776erow4_col1" class="data row4 col1" >85.245902</td>
#                         <td id="T_8cb7131a_a865_11ec_8c18_48a472d2776erow4_col2" class="data row4 col2" >85.010823</td>
#                         <td id="T_8cb7131a_a865_11ec_8c18_48a472d2776erow4_col3" class="data row4 col3" >0.069813</td>
#             </tr>
#             <tr>
#                         <th id="T_8cb7131a_a865_11ec_8c18_48a472d2776elevel0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_8cb7131a_a865_11ec_8c18_48a472d2776erow5_col0" class="data row5 col0" >Random Forest</td>
#                         <td id="T_8cb7131a_a865_11ec_8c18_48a472d2776erow5_col1" class="data row5 col1" >83.606557</td>
#                         <td id="T_8cb7131a_a865_11ec_8c18_48a472d2776erow5_col2" class="data row5 col2" >83.225108

# %%
# skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)

# results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})

# for model_name, model in tree_classifiers.items():
#     start_time = time.time()
        
#     # TRAIN AND GET PREDICTIONS USING cross_val_predict() and x,y
#     pred = cross_val_predict(model, x,y, cv=skf)

#     total_time = time.time() - start_time

#     results = results.append({"Model":    model_name,
#                               "Accuracy": accuracy_score(y, pred)*100,
#                               "Bal Acc.": balanced_accuracy_score(y, pred)*100,
#                               "Time":     total_time},
#                               ignore_index=True)
                              
                              
# results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
# results_ord.index += 1 
# results_ord.style.bar(subset=['Accuracy','Bal Acc.'], vmin=0, vmax=100, color='#5fba7d')
