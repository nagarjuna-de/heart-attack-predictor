# %%
# Import libraries
import os
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import register_matplotlib_converters  #Register pandas formatters and converters with matplotlib.
from pylab import rcParams      # for customizing matplotlib graphs.
sns.set_style("whitegrid")

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import accuracy_score, balanced_accuracy_score, plot_confusion_matrix
from sklearn import set_config
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline  
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import MinMaxScaler

# %%
from sklearn.tree          import DecisionTreeClassifier
from sklearn.ensemble      import RandomForestClassifier
from sklearn.ensemble      import ExtraTreesClassifier
from sklearn.ensemble      import AdaBoostClassifier
from sklearn.ensemble      import GradientBoostingClassifier
from sklearn.experimental  import enable_hist_gradient_boosting # Necesary for HistGradientBoostingClassifier
from sklearn.ensemble      import HistGradientBoostingClassifier
from xgboost               import XGBClassifier
from lightgbm              import LGBMClassifier
from catboost              import CatBoostClassifier
from sklearn.neighbors     import KNeighborsClassifier
from sklearn.linear_model  import LogisticRegression
from sklearn.svm           import SVC

# %%
df = pd.read_csv('heart.csv')
df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace = True)

# %%
## chainging numerical col 'chol' into categorical column:
df['chol']= pd.cut(df['chol'], bins=[0,200,239,564], labels = [0,1,2]) #0-High, 1-Borderline high, 2-High
df['trtbps']= pd.cut(df['trtbps'], bins=[94,120,139,200], labels = [0,1,2])
df['age'] = pd.cut(df['age'], bins=[29,53,80], labels = [0, 1])
df = df.astype({'trtbps':'float64','chol':'float64', 'age':'float64'})

# %%
df['chol_bps'] = df['chol']+df['trtbps']
df.drop(['chol','trtbps'], axis=1, inplace=True)
df
# Out:
#      age  sex  cp  fbs  restecg  thalachh  exng  oldpeak  slp  caa  thall  \
# 0    1.0    1   3    1        0       150     0      2.3    0    0      1
# 1    0.0    1   2    0        1       187     0      3.5    0    0      2
# 2    0.0    0   1    0        0       172     0      1.4    2    0      2
# 3    1.0    1   1    0        1       178     0      0.8    2    0      2
# 4    1.0    0   0    0        1       163     1      0.6    2    0      2
# ..   ...  ...  ..  ...      ...       ...   ...      ...  ...  ...    ...
# 297  1.0    0   0    0        1       123     1      0.2    1    0      3
# 298  0.0    1   3    0        1       132     0      1.2    1    0      3
# 299  1.0    1   0    1        1       141     0      3.4    1    2      3
# 300  1.0    1   0    0        1       115     1      1.2    1    1      3
# 301  1.0    0   1    0        0       174     0      0.0    1    1      2
#
#      output  chol_bps
# 0         1       3.0
# 1         1       3.0
# 2         1       2.0
# 3         1       1.0
# 4         1       2.0
# ..      ...       ...
# 297       0       4.0
# 298       0       2.0
# 299       0       2.0
# 300       0       1.0
# 301       0       2.0
#
# [302 rows x 13 columns]

# %%
# data agumentation
new_df = df.copy()
def get_data(data):
    gen_data = data
    for restecg_values in data['restecg'].unique():
        new_data = gen_data[gen_data['restecg']== restecg_values]
        thalachh_std = new_data['thalachh'].std()
        oldpeak_std = new_data['oldpeak'].std()

        for i in gen_data[gen_data['restecg']== restecg_values].index:
            if np.random.randint(2)==1:
                gen_data['thalachh'].values[i] += thalachh_std/10   
            else:
                gen_data['thalachh'].values[i] -= thalachh_std/10
            if np.random.randint(2)==1:
                gen_data['oldpeak'].values[i] += oldpeak_std/10
            else:
                gen_data['oldpeak'].values[i] -= oldpeak_std/10
    return gen_data
print(df.head())  
std_data = get_data(new_df)
std_data.head()
# Out:
#    age  sex  cp  fbs  restecg  thalachh  exng  oldpeak  slp  caa  thall  \
# 0  1.0    1   3    1        0       150     0      2.3    0    0      1
# 1  0.0    1   2    0        1       187     0      3.5    0    0      2
# 2  0.0    0   1    0        0       172     0      1.4    2    0      2
# 3  1.0    1   1    0        1       178     0      0.8    2    0      2
# 4  1.0    0   0    0        1       163     1      0.6    2    0      2
#
#    output  chol_bps
# 0       1       3.0
# 1       1       3.0
# 2       1       2.0
# 3       1       1.0
# 4       1       2.0
#    age  sex  cp  fbs  restecg  thalachh  exng   oldpeak  slp  caa  thall  \
# 0  1.0    1   3    1        0       152     0  2.178532    0    0      1
# 1  0.0    1   2    0        1       189     0  3.394439    0    0      2
# 2  0.0    0   1    0        0       174     0  1.521468    2    0      2
# 3  1.0    1   1    0        1       175     0  0.905561    2    0      2
# 4  1.0    0   0    0        1       160     1  0.705561    2    0      2
#
#    output  chol_bps
# 0       1       3.0
# 1       1       3.0
# 2       1       2.0
# 3       1       1.0
# 4       1       2.0

# %%
x= df.drop(['output'], axis=1)
y = df.output
cat_fe = [ 'sex','cp','fbs','restecg','exng','slp','caa','thall','age']
num_fe = ['thalachh','oldpeak','chol_bps']

x_train, x_test, y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=0, stratify=y)

extra_sample = std_data.sample(std_data.shape[0]//3)
x_train = pd.concat([x_train, extra_sample.drop(['output'], axis=1)])
y_train = pd.concat([y_train, extra_sample['output']])

# %%
s_col = ['oldpeak', 'chol_bps']
scaler = MinMaxScaler()
for d in s_col:
    train_array = x_train[d].to_numpy()
    test_array = x_test[d].to_numpy()
    train_array = train_array.reshape(-1,1)
    test_array = test_array.reshape(-1,1)

    scaler.fit(train_array)
    x_train[d] = scaler.transform(train_array)
    x_test[d] = scaler.transform(test_array)

x_train.head()
# Out:
# C:\Users\rnr31\AppData\Local\Temp\ipykernel_6424\866375025.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test[d] = scaler.transform(test_array)
# C:\Users\rnr31\AppData\Local\Temp\ipykernel_6424\866375025.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test[d] = scaler.transform(test_array)
#      age  sex  cp  fbs  restecg  thalachh  exng   oldpeak  slp  caa  thall  \
# 268  1.0    1   0    1        0       103     1  0.267187    0    0      3
# 190  1.0    1   0    0        0       131     1  0.360312    1    3      3
# 15   0.0    0   2    0        1       158     0  0.267187    1    0      2
# 223  1.0    1   0    0        1       126     1  0.453437    1    1      3
# 249  0.0    1   0    0        1       122     1  0.670730    1    3      3
#
#      chol_bps
# 268      0.75
# 190      0.50
# 15       0.25
# 223      0.25
# 249      1.00

# %%
num_4_classifiers = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value=-9999))
])
cat_4_classifiers = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value=-9999))
])
classifier_prepro = ColumnTransformer(transformers=[
    ('num', num_4_classifiers, num_fe),
    ('cat',cat_4_classifiers, cat_fe)
], remainder='drop')

# %%
tree_classifiers = {
  "KNN": KNeighborsClassifier(),
  "svm": SVC(),
  "Logistic": LogisticRegression(),
  "Decision Tree": DecisionTreeClassifier(),
  "Extra Trees": ExtraTreesClassifier(n_estimators=100),
  "Random Forest": RandomForestClassifier(n_estimators=100),
  "AdaBoost": AdaBoostClassifier(n_estimators=100),
  "Skl GBM": GradientBoostingClassifier(n_estimators=100),
  "Skl HistGBM": HistGradientBoostingClassifier(max_iter=100),
  "XGBoost": XGBClassifier(n_estimators=100),
  "LightGBM": LGBMClassifier(n_estimators=100),
  "CatBoost":  CatBoostClassifier(n_estimators=100),
}
tree_classifiers= {name:make_pipeline(classifier_prepro, model) for name, model in tree_classifiers.items()}
tree_classifiers["AdaBoost"]
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value=-9999,
#                                                                                  strategy='constant'))]),
#                                                   ['thalachh', 'oldpeak',
#                                                    'chol_bps']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value=-9999,
#                                                                                  strategy='constant'))]),
#                                                   ['sex', 'cp', 'fbs',
#                                                    'restecg', 'exng', 'slp',
#                                                    'caa', 'thall', 'age'])])),
#                 ('adaboostclassifier', AdaBoostClassifier(n_estimators=100))])

# %%
results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [], 'Time': []})
# 87:	learn: 0.2755550	total: 93ms	remaining: 12.7ms
# 88:	learn: 0.2740498	total: 93.6ms	remaining: 11.6ms
# 89:	learn: 0.2728143	total: 94.3ms	remaining: 10.5ms
# 90:	learn: 0.2709710	total: 94.9ms	remaining: 9.38ms
# 91:	learn: 0.2694215	total: 95.5ms	remaining: 8.3ms
# 92:	learn: 0.2678601	total: 96.1ms	remaining: 7.24ms
# 93:	learn: 0.2660697	total: 96.8ms	remaining: 6.18ms
# 94:	learn: 0.2642317	total: 97.5ms	remaining: 5.13ms
# 95:	learn: 0.2633928	total: 98.1ms	remaining: 4.09ms
# 96:	learn: 0.2621700	total: 98.8ms	remaining: 3.06ms
# 97:	learn: 0.2604574	total: 99.5ms	remaining: 2.03ms
# 98:	learn: 0.2591611	total: 100ms	remaining: 1.01ms
# 99:	learn: 0.2581276	total: 103ms	remaining: 0us
# <style  type="text/css" >
# #T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow0_col1,#T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow1_col1,#T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 90.2%, transparent 90.2%);
#         }#T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 89.8%, transparent 89.8%);
#         }#T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow1_col2,#T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 90.1%, transparent 90.1%);
#         }#T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow3_col1,#T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 88.5%, transparent 88.5%);
#         }#T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 88.6%, transparent 88.6%);
#         }#T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 88.3%, transparent 88.3%);
#         }#T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 86.9%, transparent 86.9%);
#         }#T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 87.1%, transparent 87.1%);
#         }#T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 85.2%, transparent 85.2%);
#         }#T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow6_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 85.6%, transparent 85.6%);
#         }#T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 83.6%, transparent 83.6%);
#         }#T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow7_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 83.5%, transparent 83.5%);
#         }#T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 80.3%, transparent 80.3%);
#         }#T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow8_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 80.2%, transparent 80.2%);
#         }#T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow9_col1,#T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow10_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 78.7%, transparent 78.7%);
#         }#T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow9_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 78.1%, transparent 78.1%);
#         }#T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow10_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 79.0%, transparent 79.0%);
#         }#T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow11_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 54.1%, transparent 54.1%);
#         }#T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow11_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 50.0%, transparent 50.0%);
#         }</style><table id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >Bal Acc.</th>        <th class="col_heading level0 col3" >Time</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776elevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow0_col0" class="data row0 col0" >Logistic</td>
#                         <td id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow0_col1" class="data row0 col1" >90.163934</td>
#                         <td id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow0_col2" class="data row0 col2" >89.826840</td>
#                         <td id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow0_col3" class="data row0 col3" >0.048839</td>
#             </tr>
#             <tr>
#                         <th id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776elevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow1_col0" class="data row1 col0" >Extra Trees</td>
#                         <td id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow1_col1" class="data row1 col1" >90.163934</td>
#                         <td id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow1_col2" class="data row1 col2" >90.097403</td>
#                         <td id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow1_col3" class="data row1 col3" >13.903031</td>
#             </tr>
#             <tr>
#                         <th id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776elevel0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow2_col0" class="data row2 col0" >LightGBM</td>
#                         <td id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow2_col1" class="data row2 col1" >90.163934</td>
#                         <td id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow2_col2" class="data row2 col2" >90.097403</td>
#                         <td id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow2_col3" class="data row2 col3" >0.062832</td>
#             </tr>
#             <tr>
#                         <th id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776elevel0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow3_col0" class="data row3 col0" >Skl HistGBM</td>
#                         <td id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow3_col1" class="data row3 col1" >88.524590</td>
#                         <td id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow3_col2" class="data row3 col2" >88.582251</td>
#                         <td id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow3_col3" class="data row3 col3" >0.428853</td>
#             </tr>
#             <tr>
#                         <th id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776elevel0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow4_col0" class="data row4 col0" >CatBoost</td>
#                         <td id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow4_col1" class="data row4 col1" >88.524590</td>
#                         <td id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow4_col2" class="data row4 col2" >88.311688</td>
#                         <td id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow4_col3" class="data row4 col3" >0.210131</td>
#             </tr>
#             <tr>
#                         <th id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776elevel0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow5_col0" class="data row5 col0" >XGBoost</td>
#                         <td id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow5_col1" class="data row5 col1" >86.885246</td>
#                         <td id="T_bd409ef1_a7dd_11ec_92c7_48a472d2776erow5_col2" class="data row5 col2" >8
